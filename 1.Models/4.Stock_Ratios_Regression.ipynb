# %% [markdown]
# # Import the Data

# %%
import pandas as pd

df = pd.read_csv("data/stocks.csv")

# %%
df.head()
# Out:
#   symbol    market_cap   pe_ratio period_ending fiscal_period  calendar_year  \
# 0      A  3.778990e+10  29.317223    2024-10-31            FY           2024
# 1      A  3.039078e+10  24.508694    2023-10-31            FY           2023
# 2      A  4.136665e+10  32.987759    2022-10-31            FY           2022
# 3      A  4.774624e+10  39.459702    2021-10-31            FY           2021
# 4      A  3.154581e+10  43.874562    2020-10-31            FY           2020
#
#    revenue_per_share  capex_per_share  net_income_per_share  \
# 0          22.448276         1.303448              4.444828
# 1          23.241497         1.013605              4.217687
# 2          22.903010         0.973244              4.193980
# 3          20.786184         0.621711              3.980263
# 4          17.278317         0.385113              2.326861
#
#    operating_cash_flow_per_share  ...  receivables_turnover  \
# 0                       6.037931  ...              4.916918
# 1                       6.027211  ...              5.292796
# 2                       4.387960  ...              4.874021
# 3                       4.884868  ...              5.391638
# 4                       2.980583  ...              5.143545
#
#    payables_turnover  inventory_turnover  return_on_equity  \
# 0           5.509259            3.060700          0.218549
# 1           8.057416            3.266731          0.212147
# 2           5.389655            3.011561          0.236381
# 3           6.529148            3.508434          0.224531
# 4           7.067797            3.475000          0.147548
#
#    return_on_invested_capital  return_on_tangible_assets  dividend_yield  \
# 0                    0.126154                   0.188948        0.007251
# 1                    0.136483                   0.195954        0.008720
# 2                    0.154036                   0.217746        0.006044
# 3                    0.132438                   0.210471        0.004943
# 4                    0.087185                   0.138429        0.007037
#
#    graham_number  graham_net_net  Stock
# 0      45.099539      -10.827586      A
# 1      43.435720       -6.272959      A
# 2      40.917730       -8.699833      A
# 3      39.844140       -8.049342      A
# 4      28.733957       -7.037217      A
#
# [5 rows x 62 columns]

# %%
df.shape
# Out:
# (3357, 61)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3357 entries, 0 to 3356
# Data columns (total 61 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Stock                                     3357 non-null   object
#  1   return                                    3357 non-null   float64
#  2   adjusted_price                            3357 non-null   float64
#  3   close_price                               3357 non-null   float64
#  4   period_ending                             3357 non-null   object
#  5   fiscal_period                             3357 non-null   object
#  6   fiscal_year                               3357 non-null   int64
#  7   current_ratio                             3269 non-null   float64
#  8   quick_ratio                               3269 non-null   float64
#  9   cash_ratio                                3258 non-null   float64
#  10  days_of_sales_outstanding                 3042 non-null   float64
#  11  days_of_inventory_outstanding             2491 non-null   float64
#  12  operating_cycle                           3122 non-null   float64
#  13  days_of_payables_outstanding              2919 non-null   float64
#  14  cash_conversion_cycle                     3166 non-null   float64
#  15  gross_profit_margin                       3326 non-null   float64
#  16  operating_profit_margin                   3265 non-null   float64
#  17  pretax_profit_margin                      3337 non-null   float64
#  18  net_profit_margin                         3337 non-null   float64
#  19  effective_tax_rate                        3328 non-null   float64
#  20  return_on_assets                          3330 non-null   float64
#  21  return_on_equity                          3330 non-null   float64
#  22  return_on_capital_employed                3260 non-null   float64
#  23  net_income_per_ebt                        3348 non-null   float64
#  24  ebt_per_ebit                              3276 non-null   float64
#  25  ebit_per_revenue                          3265 non-null   float64
#  26  debt_ratio                                3296 non-null   float64
#  27  debt_equity_ratio                         3293 non-null   float64
#  28  long_term_debt_to_capitalization          2981 non-null   float64
#  29  total_debt_to_capitalization              3296 non-null   float64
#  30  cash_flow_to_debt_ratio                   3283 non-null   float64
#  31  company_equity_multiplier                 3332 non-null   float64
#  32  receivables_turnover                      3042 non-null   float64
#  33  payables_turnover                         2919 non-null   float64
#  34  inventory_turnover                        2491 non-null   float64
#  35  fixed_asset_turnover                      3252 non-null   float64
#  36  asset_turnover                            3321 non-null   float64
#  37  operating_cash_flow_per_share             3331 non-null   float64
#  38  free_cash_flow_per_share                  3332 non-null   float64
#  39  cash_per_share                            3316 non-null   float64
#  40  payout_ratio                              2515 non-null   float64
#  41  operating_cash_flow_sales_ratio           3326 non-null   float64
#  42  free_cash_flow_operating_cash_flow_ratio  3339 non-null   float64
#  43  cash_flow_coverage_ratios                 3283 non-null   float64
#  44  short_term_coverage_ratios                2560 non-null   float64
#  45  capital_expenditure_coverage_ratio        3140 non-null   float64
#  46  dividend_paid_and_capex_coverage_ratio    3313 non-null   float64
#  47  dividend_payout_ratio                     2515 non-null   float64
#  48  price_book_value_ratio                    3327 non-null   float64
#  49  price_to_book_ratio                       3327 non-null   float64
#  50  price_to_sales_ratio                      3330 non-null   float64
#  51  price_earnings_ratio                      3341 non-null   float64
#  52  price_to_free_cash_flows_ratio            3332 non-null   float64
#  53  price_to_operating_cash_flows_ratio       3331 non-null   float64
#  54  price_cash_flow_ratio                     3331 non-null   float64
#  55  price_earnings_to_growth_ratio            3321 non-null   float64
#  56  price_sales_ratio                         3330 non-null   float64
#  57  dividend_yield                            2510 non-null   float64
#  58  enterprise_value_multiple                 3219 non-null   float64
#  59  price_fair_value                          3327 non-null   float64
#  60  interest_coverage                         3042 non-null   float64
# dtypes: float64(57), int64(1), object(3)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#             return  adjusted_price  close_price  fiscal_year  current_ratio  \
# count  3357.000000     3357.000000  3357.000000  3357.000000   3.269000e+03
# mean      0.254881      144.149912   146.098588  2022.379506   2.218784e+03
# std       1.609133      318.167095   318.060520     1.180961   1.261828e+05
# min      -0.979550        0.351800     0.904000  2020.000000  -1.207344e+00
# 25%      -0.089162       32.860001    35.660000  2021.000000   9.526310e-01
# 50%       0.104446       74.690002    75.849998  2022.000000   1.354000e+00
# 75%       0.338095      163.425915   164.020004  2023.000000   2.320073e+00
# max      66.156697     8178.899902  8178.899902  2025.000000   7.214525e+06
#
#         quick_ratio    cash_ratio  days_of_sales_outstanding  \
# count  3.269000e+03  3.258000e+03                3042.000000
# mean   4.879385e+03  1.444117e+03                 406.531021
# std    2.057431e+05  5.912035e+04               16553.772517
# min   -2.143429e+01 -1.941784e+00               -1026.237212
# 25%    7.228859e-01  1.621525e-01                  33.256940
# 50%    1.085292e+00  3.662762e-01                  55.705076
# 75%    1.863554e+00  8.047852e-01                  80.929588
# max    1.039021e+07  2.783903e+06              911492.030060
#
#        days_of_inventory_outstanding  operating_cycle  ...  \
# count                   2.491000e+03     3.122000e+03  ...
# mean                   -8.974852e+08    -7.160904e+08  ...
# std                     3.236016e+10     2.890661e+10  ...
# min                    -1.352819e+12    -1.352819e+12  ...
# 25%                     1.968370e+01     6.058160e+01  ...
# 50%                     5.949163e+01     1.059591e+02  ...
# 75%                     1.095019e+02     1.738482e+02  ...
# max                     8.687000e+04     9.114920e+05  ...
#
#        price_earnings_ratio  price_to_free_cash_flows_ratio  \
# count           3341.000000                     3332.000000
# mean              44.567515                       -0.627078
# std             1352.300134                     1295.499141
# min           -50860.861063                   -64422.616579
# 25%               10.076951                        7.308444
# 50%               19.534143                       18.673788
# 75%               32.247395                       32.374021
# max            41044.843398                    20532.021081
#
#        price_to_operating_cash_flows_ratio  price_cash_flow_ratio  \
# count                          3331.000000            3331.000000
# mean                              3.030877               3.030877
# std                            1203.793645            1203.793645
# min                          -64422.616579          -64422.616579
# 25%                               6.982197               6.982197
# 50%                              14.287013              14.287013
# 75%                              24.074604              24.074604
# max                           17341.881818           17341.881818
#
#        price_earnings_to_growth_ratio  price_sales_ratio  dividend_yield  \
# count                     3321.000000        3330.000000     2510.000000
# mean                        -0.116693          12.608792        0.050253
# std                         19.604428         366.414420        0.975755
# min                       -410.657310         -68.940568        0.000003
# 25%                         -0.517442           1.482062        0.011356
# 50%                          0.139026           2.863082        0.021469
# 75%                          0.982282           5.623189        0.036593
# max                        508.437227       20992.687770       48.781099
#
#        enterprise_value_multiple  price_fair_value  interest_coverage
# count                3219.000000       3327.000000        3042.000000
# mean                  -25.473482          8.790017         -39.011577
# std                  2584.680301        621.800273        3656.757029
# min               -137035.779167     -20613.985237     -176158.000000
# 25%                     7.728815          1.560106           2.582171
# 50%                    13.467717          3.012962           6.780716
# 75%                    20.609821          6.746772          15.913089
# max                 40665.587360      26229.799716       12159.422535
#
# [8 rows x 58 columns]

# %%
df.columns
# Out:
# Index(['Stock', 'return', 'adjusted_price', 'close_price', 'period_ending',
#        'fiscal_period', 'fiscal_year', 'current_ratio', 'quick_ratio',
#        'cash_ratio', 'days_of_sales_outstanding',
#        'days_of_inventory_outstanding', 'operating_cycle',
#        'days_of_payables_outstanding', 'cash_conversion_cycle',
#        'gross_profit_margin', 'operating_profit_margin',
#        'pretax_profit_margin', 'net_profit_margin', 'effective_tax_rate',
#        'return_on_assets', 'return_on_equity', 'return_on_capital_employed',
#        'net_income_per_ebt', 'ebt_per_ebit', 'ebit_per_revenue', 'debt_ratio',
#        'debt_equity_ratio', 'long_term_debt_to_capitalization',
#        'total_debt_to_capitalization', 'cash_flow_to_debt_ratio',
#        'company_equity_multiplier', 'receivables_turnover',
#        'payables_turnover', 'inventory_turnover', 'fixed_asset_turnover',
#        'asset_turnover', 'operating_cash_flow_per_share',
#        'free_cash_flow_per_share', 'cash_per_share', 'payout_ratio',
#        'operating_cash_flow_sales_ratio',
#        'free_cash_flow_operating_cash_flow_ratio', 'cash_flow_coverage_ratios',
#        'short_term_coverage_ratios', 'capital_expenditure_coverage_ratio',
#        'dividend_paid_and_capex_coverage_ratio', 'dividend_payout_ratio',
#        'price_book_value_ratio', 'price_to_book_ratio', 'price_to_sales_ratio',
#        'price_earnings_ratio', 'price_to_free_cash_flows_ratio',
#        'price_to_operating_cash_flows_ratio', 'price_cash_flow_ratio',
#        'price_earnings_to_growth_ratio', 'price_sales_ratio', 'dividend_yield',
#        'enterprise_value_multiple', 'price_fair_value', 'interest_coverage'],
#       dtype='object')

# %%
def growth (df, col_ratios):

    df = df.sort_values(by=["Stock", "fiscal_year"]).copy()
    df[col_ratios] = df.groupby("Stock")[col_ratios].transform(lambda x: x.fillna(x.mean()))

    def anual_growth (group):
        return group[col_ratios].pct_change(fill_method=None)
    
    df_gr = df.groupby("Stock", group_keys=False).apply(anual_growth )
    df_gr = df_gr.add_suffix("_growth")
    df_gr = df_gr.groupby(df['Stock']).transform(lambda x: x.fillna(x.mean()))
    df = pd.concat([df, df_gr], axis=1)

    return df

# %%
growth_ratios = ['operating_cash_flow_per_share', 'free_cash_flow_per_share']

df = growth (df, growth_ratios)
df.head()
# Out:
# /var/folders/n8/s5gn3hhs4z90dmrnk47r93fh0000gn/T/ipykernel_3293/2541788003.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_gr = df.groupby("Stock", group_keys=False).apply(anual_growth )
#   Stock    return  adjusted_price  close_price period_ending fiscal_period  \
# 0     A  0.538447      157.059998   157.059998    2021-10-31            FY
# 1     A -0.119126      138.350006   138.350006    2022-10-31            FY
# 2     A -0.252837      103.370003   103.370003    2023-10-31            FY
# 3     A  0.260617      130.309998   130.309998    2024-10-31            FY
# 4  AAPL  0.308514      146.919998   146.919998    2021-09-25            FY
#
#    fiscal_year  current_ratio  quick_ratio  cash_ratio  ...  \
# 0         2021       2.224239     1.738290    0.868852  ...
# 1         2022       2.030091     1.472327    0.565825  ...
# 2         2023       2.611354     1.968185    0.991890  ...
# 3         2024       2.089182     1.576253    0.701319  ...
# 4         2021       1.074553     1.022115    0.278449  ...
#
#    price_to_operating_cash_flows_ratio  price_cash_flow_ratio  \
# 0                            32.152350              32.152350
# 1                            31.529459              31.529459
# 2                            17.150553              17.150553
# 3                            21.581896              21.581896
# 4                            23.585141              23.585141
#
#    price_earnings_to_growth_ratio  price_sales_ratio  dividend_yield  \
# 0                        0.557219           7.555980        0.004943
# 1                        6.251966           6.040691        0.006044
# 2                       34.230475           4.447648        0.008720
# 3                        5.623576           5.804900        0.007251
# 4                        0.363486           6.707591        0.005896
#
#    enterprise_value_multiple  price_fair_value  interest_coverage  \
# 0                  28.400719          8.859944          16.629630
# 1                  21.606143          7.797672          19.261905
# 2                  18.517780          5.199449          14.210526
# 3                  26.781519          6.407240          15.500000
# 4                  21.253174         38.892865          41.190548
#
#    operating_cash_flow_per_share_growth  free_cash_flow_per_share_growth
# 0                              0.091211                         0.071182
# 1                             -0.101724                        -0.199017
# 2                              0.373579                         0.468235
# 3                              0.001779                        -0.055673
# 4                              0.079666                         0.092097
#
# [5 rows x 63 columns]

# %%
ratios = [
    "gross_profit_margin", "operating_profit_margin", "net_profit_margin", "return_on_equity", "return_on_capital_employed",  # Profitability
    "asset_turnover", "inventory_turnover", "operating_cycle",  # Eficciency
    "current_ratio", "debt_equity_ratio", "capital_expenditure_coverage_ratio",  # Liquidity and Solvency
    "price_to_free_cash_flows_ratio", "price_earnings_ratio", "price_to_book_ratio", "price_fair_value",  # Valuation
    'operating_cash_flow_per_share_growth', 'free_cash_flow_per_share_growth','price_earnings_to_growth_ratio'  # Growth
]

# %%
import matplotlib.pyplot as plt

plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

df_ratios = df[ratios]
df_ratios.hist(bins=50, figsize=(15,12))

plt.show()

# %% [markdown]
# # Create a Test Set

# %%
import numpy as np

df["return_cat"] = pd.cut(df["return"],
                               bins = [-np.inf, -0.09, 0.10, 0.34, 1.6, np.inf],
                               labels = ['Very Low', 'Low', 'Medium', 'High', 'Very High'])

# %%
plt.figure(figsize=(8, 4))

df["return_cat"].value_counts().sort_index().plot.bar(rot=0, grid=False)
plt.xlabel("Return category")
plt.ylabel("Number of companies")

plt.show()

# %%
import numpy as np

np.random.seed(42)

companies = df['Stock'].unique()

companies_test = np.random.choice(companies, size=int(len(companies) * 0.2), replace=False)

test_set = df[df['Stock'].isin(companies_test)].reset_index(drop=True)
train_set = df[~df['Stock'].isin(companies_test)].reset_index(drop=True)

# %%
len(train_set), len(test_set), len(train_set) + len(test_set)
# Out:
# (2688, 669, 3357)

# %%
def income_cat_proportions(data):
    return data["return_cat"].value_counts() / len(data)

compare_props = pd.DataFrame({
    "Overall %": income_cat_proportions(df),
    "Stratified %": income_cat_proportions(test_set),
}).sort_index()

(compare_props * 100).round(2)
# Out:
#             Overall %  Stratified %
# return_cat
# Very Low        24.87         25.71
# Low             24.52         23.17
# Medium          25.74         24.96
# High            22.64         23.92
# Very High        2.23          2.24

# %%
for set_ in (train_set, test_set):
    set_.drop("return_cat", axis=1, inplace=True)

# %%
train_set.tail()
# Out:
#      Stock    return  adjusted_price  close_price period_ending fiscal_period  \
# 2683    ZS  0.118282      179.350006   179.350006    2024-07-31            FY
# 2684   ZTS  0.474502      244.029999   244.029999    2021-12-31            FY
# 2685   ZTS -0.399459      146.550003   146.550003    2022-12-31            FY
# 2686   ZTS  0.341317      196.570007   196.570007    2023-12-31            FY
# 2687   ZTS -0.171135      162.929993   162.929993    2024-12-31            FY
#
#       fiscal_year  current_ratio  quick_ratio  cash_ratio  ...  \
# 2683         2024       1.091147     1.091147    0.457158  ...
# 2684         2021       3.856427     2.786311    1.937674  ...
# 2685         2022       2.370066     1.629618    1.129460  ...
# 2686         2023       3.357861     2.000529    1.079407  ...
# 2687         2024       1.754396     1.078546    0.581770  ...
#
#       price_to_operating_cash_flows_ratio  price_cash_flow_ratio  \
# 2683                            34.401983              34.401983
# 2684                            52.306888              52.306888
# 2685                            35.939318              35.939318
# 2686                            38.683178              38.683178
# 2687                            25.060212              25.060212
#
#       price_earnings_to_growth_ratio  price_sales_ratio  dividend_yield  \
# 2683                        6.444334          12.375961             NaN
# 2684                        2.299793          14.886207        0.004095
# 2685                        6.338512           8.504452        0.008892
# 2686                        3.072474          10.653268        0.007603
# 2687                        3.877450           7.995117        0.010621
#
#       enterprise_value_multiple  price_fair_value  interest_coverage  \
# 2683                 411.210244         21.056594          -9.250457
# 2684                  37.520852         25.479890          12.299107
# 2685                  21.807319         15.599541          13.067873
# 2686                  25.980330         18.215233          12.841004
# 2687                  20.431078         15.514215          27.786667
#
#       operating_cash_flow_per_share_growth  free_cash_flow_per_share_growth
# 2683                              0.634361                         0.698914
# 2684                              0.133182                         0.151685
# 2685                             -0.125959                        -0.227286
# 2686                              0.251247                         0.242935
# 2687                              0.274258                         0.439404
#
# [5 rows x 63 columns]

# %% [markdown]
# # Discover and Visualize the Data

# %%
stocks = train_set.copy()

# %%
profitability = ["gross_profit_margin", "operating_profit_margin", "return_on_capital_employed", "return"]
efficiency = ["asset_turnover", "inventory_turnover", "operating_cycle", "return"]
liquidity_solvency = ["current_ratio", "debt_equity_ratio", "interest_coverage", "return"]
valuation = ["price_to_free_cash_flows_ratio", "price_earnings_ratio", "price_to_book_ratio", "return"]
growth = ["operating_cash_flow_per_share_growth", "free_cash_flow_per_share_growth", "price_earnings_to_growth_ratio", "return"]

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(stocks[profitability], figsize=(10, 6))
plt.show()

# %%
stocks_clean = stocks.copy()
for col in ratios:
    Q1 = stocks_clean[col].quantile(0.25)
    Q3 = stocks_clean[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    stocks_clean = stocks_clean[(stocks_clean[col] >= lower_bound) & (stocks_clean[col] <= upper_bound)]

# %%
scatter_matrix(stocks_clean[profitability], figsize=(10, 6))
plt.show()

# %%
scatter_matrix(stocks_clean[efficiency], figsize=(10, 6))
plt.show()

# %%
scatter_matrix(stocks_clean[liquidity_solvency], figsize=(10, 6))
plt.show()

# %%
scatter_matrix(stocks_clean[valuation], figsize=(10, 6))
plt.show()

# %%
scatter_matrix(stocks_clean[growth], figsize=(10, 6))
plt.show()

# %%
import seaborn as sns

ratios_r = ratios + ["return"]

correlation_matrix = stocks[ratios_r].corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="viridis", fmt=".2f", 
            linewidths=0.5, annot_kws={"size": 10}, vmax=1, vmin=-1)

plt.xticks(rotation=90, fontsize=9)
plt.yticks(rotation=0, fontsize=9)

plt.title('Heatmap: Correlation Matrix')
plt.show()

# %%
correlation_matrix = stocks_clean[ratios_r].corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="viridis", fmt=".2f", 
            linewidths=0.5, annot_kws={"size": 10}, vmax=1, vmin=-1)

plt.xticks(rotation=90, fontsize=9)
plt.yticks(rotation=0, fontsize=9)

plt.title('Heatmap: Correlation Matrix')
plt.show()

# %% [markdown]
# # Prepare the Data

# %%
train = train_set.drop("return", axis=1)
train_label = train_set[["return"]].copy()

# %%
outliers_dict = {}

for column in ratios:
    Q1 = train[column].quantile(0.25)
    Q3 = train[column].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    
    outliers = train[(train[column] < lower_bound) | (train[column] > upper_bound)]
    
    outliers_dict[column] = outliers

    print(f"Outliers in {column}: {outliers.shape[0]} outliers found.")
# Out:
# Outliers in gross_profit_margin: 24 outliers found.
# Outliers in operating_profit_margin: 217 outliers found.
# Outliers in net_profit_margin: 226 outliers found.
# Outliers in return_on_equity: 400 outliers found.
# Outliers in return_on_capital_employed: 199 outliers found.
# Outliers in asset_turnover: 160 outliers found.
# Outliers in inventory_turnover: 276 outliers found.
# Outliers in operating_cycle: 235 outliers found.
# Outliers in current_ratio: 284 outliers found.
# Outliers in debt_equity_ratio: 329 outliers found.
# Outliers in capital_expenditure_coverage_ratio: 336 outliers found.
# Outliers in price_to_free_cash_flows_ratio: 382 outliers found.
# Outliers in price_earnings_ratio: 420 outliers found.
# Outliers in price_to_book_ratio: 384 outliers found.
# Outliers in price_fair_value: 384 outliers found.
# Outliers in operating_cash_flow_per_share_growth: 424 outliers found.
# Outliers in free_cash_flow_per_share_growth: 458 outliers found.
# Outliers in price_earnings_to_growth_ratio: 483 outliers found.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
sns.histplot(train['return_on_capital_employed'], bins=50, kde=True)
plt.title(f"Distribution {'return_on_capital_employed'}")
plt.show()

# %%
train["return_on_capital_employed_log"] = np.log1p(train["return_on_capital_employed"] - train["return_on_capital_employed"].min() + 1)

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['return_on_capital_employed_log'], bins=50, kde=True)
plt.title(f"Distribution {'return_on_capital_employed_log'}")
plt.show()

# %%
train["return_on_capital_employed_log"].describe()
# Out:
# count    2609.000000
# mean        3.664166
# std         0.058906
# min         0.693147
# 25%         3.663540
# 50%         3.664851
# 75%         3.666924
# max         3.829003
# Name: return_on_capital_employed_log, dtype: float64

# %%
from scipy.stats.mstats import winsorize

train["return_on_capital_employed_wins"] = winsorize(train["return_on_capital_employed_log"], limits=[0.01, 0.01])

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['return_on_capital_employed_wins'], bins=50, kde=True)
plt.title(f"Distribution {'return_on_capital_employed_wins'}")
plt.show()

# %%
train["return_on_capital_employed_wins"].describe()
# Out:
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/numpy/lib/function_base.py:4824: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# count    2609.000000
# mean        3.665527
# std         0.005752
# min         3.654111
# 25%         3.663540
# 50%         3.664851
# 75%         3.666924
# max         3.829003
# Name: return_on_capital_employed_wins, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
train['return_on_capital_employed_scaled'] = scaler.fit_transform(train[['return_on_capital_employed_wins']])

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['return_on_capital_employed_scaled'], bins=50, kde=True)
plt.title(f"Distribution {'return_on_capital_employed_scaled'}")
plt.show()

# %%
from sklearn.preprocessing import RobustScaler

def preprocess_column(df, columns, winsor_limits=(0.04, 0.04)):
    scaler = RobustScaler()
    
    for column in columns:
    
        df[f"{column}_log"] = np.log1p(df[column] - df[column].min() + 1)
        
        df[f"{column}_wins"] = winsorize(df[f"{column}_log"], limits=winsor_limits)
        
        df[f"{column}_scaled"] = scaler.fit_transform(df[[f"{column}_wins"]])

    return df

# %%
train = preprocess_column(train, ratios)

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['return_on_capital_employed_scaled'], bins=50, kde=True)
plt.title(f"Distribution {'return_on_capital_employed_scaled'}")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['price_earnings_ratio_scaled'], bins=50, kde=True)
plt.title(f"Distribution {'price_earnings_ratio_scaled'}")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['capital_expenditure_coverage_ratio_scaled'], bins=50, kde=True)
plt.title(f"Distribution {'capital_expenditure_coverage_ratio_scaled'}")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['net_profit_margin_scaled'], bins=50, kde=True)
plt.title(f"Distribution {'net_profit_margin_scaled'}")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['operating_cycle_scaled'], bins=50, kde=True)
plt.title(f"Distribution {'operating_cycle_scaled'}")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['return_on_equity_scaled'], bins=50, kde=True)
plt.title(f"Distribution {'return_on_equity_scaled'}")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['price_fair_value_scaled'], bins=50, kde=True)
plt.title(f"Distribution {'price_fair_value_scaled'}")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['free_cash_flow_per_share_growth_scaled'], bins=50, kde=True)
plt.title(f"Distribution {'free_cash_flow_per_share_growth_scaled'}")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['debt_equity_ratio_scaled'], bins=50, kde=True)
plt.title(f"Distribution {'debt_equity_ratio_scaled'}")
plt.show()

# %%
train_label["log_return"] = np.log1p(train_label["return"])  # log1p(x) = log(1 + x)

plt.figure(figsize=(8, 5))

fig, axes = plt.subplots(1, 2, figsize=(14, 5))  

sns.histplot(train_label["return"], bins=50, kde=True, ax=axes[0], color="blue")
axes[0].set_title("Histogram of Return")
axes[0].set_xlabel("Return")
axes[0].set_ylabel("Frequency")

sns.histplot(train_label["log_return"], bins=50, kde=True, ax=axes[1], color="#2E2E2E")
axes[1].set_title("Histogram of Log(1 + Return)")
axes[1].set_xlabel("Log(1 + Return)")
axes[1].set_ylabel("Frequency")


plt.tight_layout()
plt.show()

# %%
missing_values_percent = train.isnull().sum() / len(train) * 100

missing_values_percent[missing_values_percent > 20]
# Out:
# days_of_inventory_outstanding    25.744048
# inventory_turnover               25.744048
# payout_ratio                     24.888393
# short_term_coverage_ratios       23.958333
# dividend_payout_ratio            24.888393
# dividend_yield                   25.074405
# inventory_turnover_log           25.744048
# inventory_turnover_wins          25.744048
# inventory_turnover_scaled        25.744048
# dtype: float64

# %%
from sklearn.impute import SimpleImputer

columns = ['payout_ratio', 'dividend_payout_ratio', 'dividend_yield']

imputer = SimpleImputer(strategy="constant", fill_value=0)
train[columns] = imputer.fit_transform(train[columns])

train[columns].isnull().sum()
# Out:
# payout_ratio             0
# dividend_payout_ratio    0
# dividend_yield           0
# dtype: int64

# %%
train = train.drop(["days_of_inventory_outstanding", 'inventory_turnover', 'short_term_coverage_ratios',
                    'days_of_payables_outstanding', 'payables_turnover', 'long_term_debt_to_capitalization'], axis=1)

# %%
missing_values_percent = train.isnull().sum() / len(train) * 100

missing_values_percent[missing_values_percent > 0]
# Out:
# current_ratio                               2.641369
# quick_ratio                                 2.641369
# cash_ratio                                  3.013393
# days_of_sales_outstanding                   9.077381
# operating_cycle                             6.547619
#                                               ...
# price_to_book_ratio_log                     0.930060
# price_fair_value_log                        0.930060
# operating_cash_flow_per_share_growth_log    0.260417
# free_cash_flow_per_share_growth_log         0.260417
# price_earnings_to_growth_ratio_log          1.116071
# Length: 71, dtype: float64

# %%
from sklearn.impute import KNNImputer

numeric_columns = train.select_dtypes(include=[np.number]).columns

knn_imputer = KNNImputer(n_neighbors=5)

train[numeric_columns] = knn_imputer.fit_transform(train[numeric_columns])

# %%
train.isnull().sum().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import OrdinalEncoder

unique_years = sorted(train["fiscal_year"].unique())
ordinal_encoder = OrdinalEncoder(categories=[unique_years])

# %%
train[['fiscal_year']] = ordinal_encoder.fit_transform(train[['fiscal_year']])

train[['fiscal_year']].head()
# Out:
#    fiscal_year
# 0          1.0
# 1          2.0
# 2          3.0
# 3          4.0
# 4          1.0

# %% [markdown]
# ## Transformation Pipeline

# %%
train = train_set.drop(['return'], axis=1)
train_label = train_label["log_return"].copy()

# %%
excluded_cols = ['Stock', 'adjusted_price', 'close_price', 'period_ending', 'fiscal_period',"days_of_inventory_outstanding", 'inventory_turnover', 'short_term_coverage_ratios',
                    'days_of_payables_outstanding', 'payables_turnover', 'long_term_debt_to_capitalization']

dividend_ratios = ['payout_ratio', 'dividend_payout_ratio', 'dividend_yield']

excluded_cols_2 = excluded_cols + dividend_ratios + ['fiscal_year']

ratios = [col for col in train.columns if col not in excluded_cols_2]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import RobustScaler
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import FunctionTransformer


def preprocess_column(X):
    X_log = np.log1p(X - X.min() + 1)  
    X_wins = winsorize(X_log, limits=(0.04, 0.04), axis=0)  
    return np.array(X_wins)

ratio_pipeline = make_pipeline(KNNImputer(n_neighbors=5) ,FunctionTransformer(preprocess_column, feature_names_out="one-to-one"), 
                               RobustScaler())

dividend_pipeline = make_pipeline(SimpleImputer(strategy='constant', fill_value=0) ,FunctionTransformer(preprocess_column, feature_names_out="one-to-one"), 
                               RobustScaler())

ord_pipeline = make_pipeline(ordinal_encoder) 

preprocessing = ColumnTransformer([
        ("log_wins_sc", ratio_pipeline, ratios),
        ("log_wins_sc_", dividend_pipeline, dividend_ratios),
        ("ord", ord_pipeline, ['fiscal_year']),
        ("drop_cols", "drop", excluded_cols)
    ],
    remainder='passthrough')

# %%
train_prepared = preprocessing.fit_transform(train)
train_prepared.shape
# Out:
# (2688, 51)

# %%
feature_names = preprocessing.get_feature_names_out()

train_prepared_df = pd.DataFrame(train_prepared, columns=feature_names)

train_prepared_df.head()
# Out:
#    log_wins_sc__current_ratio  log_wins_sc__quick_ratio  \
# 0                    0.597561                  0.495283
# 1                    0.463415                  0.283019
# 2                    0.865854                  0.679245
# 3                    0.504065                  0.367925
# 4                   -0.199187                 -0.080189
#
#    log_wins_sc__cash_ratio  log_wins_sc__days_of_sales_outstanding  \
# 0                 0.732759                                0.243720
# 1                 0.284483                                0.391787
# 2                 0.913793                                0.269686
# 3                 0.482759                                0.378382
# 4                -0.137931                               -0.092271
#
#    log_wins_sc__operating_cycle  log_wins_sc__cash_conversion_cycle  \
# 0                      0.661522                            0.688597
# 1                      0.881888                            0.804466
# 2                      0.742615                            0.869499
# 3                      0.858393                            0.794006
# 4                     -0.325378                           -0.670767
#
#    log_wins_sc__gross_profit_margin  log_wins_sc__operating_profit_margin  \
# 0                          0.126761                              0.212121
# 1                          0.126761                              0.333333
# 2                          0.042254                              0.121212
# 3                          0.126761                              0.303030
# 4                         -0.169014                              0.666667
#
#    log_wins_sc__pretax_profit_margin  log_wins_sc__net_profit_margin  ...  \
# 0                           0.354839                        0.500000  ...
# 1                           0.387097                        0.461538  ...
# 2                           0.258065                        0.461538  ...
# 3                           0.483871                        0.538462  ...
# 4                           0.838710                        0.961538  ...
#
#    log_wins_sc__price_sales_ratio  log_wins_sc__enterprise_value_multiple  \
# 0                        1.124476                                1.236398
# 1                        0.762238                                0.692777
# 2                        0.383217                                0.445591
# 3                        0.706294                                1.106942
# 4                        0.921678                                0.664634
#
#    log_wins_sc__price_fair_value  log_wins_sc__interest_coverage  \
# 0                       1.143503                        0.679813
# 1                       0.938983                        0.870229
# 2                       0.438418                        0.504665
# 3                       0.671186                        0.597964
# 4                       5.796610                        2.456743
#
#    log_wins_sc__operating_cash_flow_per_share_growth  \
# 0                                           0.041667
# 1                                          -0.416667
# 2                                           0.708333
# 3                                          -0.166667
# 4                                           0.013889
#
#    log_wins_sc__free_cash_flow_per_share_growth  log_wins_sc___payout_ratio  \
# 0                                      0.041322                   -0.155829
# 1                                     -0.338843                   -0.147806
# 2                                      0.603306                   -0.121163
# 3                                     -0.140496                   -0.123283
# 4                                      0.066116                   -0.234272
#
#    log_wins_sc___dividend_payout_ratio  log_wins_sc___dividend_yield  \
# 0                            -0.155829                     -0.297732
# 1                            -0.147806                     -0.262090
# 2                            -0.121163                     -0.175431
# 3                            -0.123283                     -0.223003
# 4                            -0.234272                     -0.266871
#
#    ord__fiscal_year
# 0               1.0
# 1               2.0
# 2               3.0
# 3               4.0
# 4               1.0
#
# [5 rows x 51 columns]

# %%
train_prepared_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2688 entries, 0 to 2687
# Data columns (total 51 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   log_wins_sc__current_ratio                             2688 non-null   float64
#  1   log_wins_sc__quick_ratio                               2688 non-null   float64
#  2   log_wins_sc__cash_ratio                                2688 non-null   float64
#  3   log_wins_sc__days_of_sales_outstanding                 2688 non-null   float64
#  4   log_wins_sc__operating_cycle                           2688 non-null   float64
#  5   log_wins_sc__cash_conversion_cycle                     2688 non-null   float64
#  6   log_wins_sc__gross_profit_margin                       2688 non-null   float64
#  7   log_wins_sc__operating_profit_margin                   2688 non-null   float64
#  8   log_wins_sc__pretax_profit_margin                      2688 non-null   float64
#  9   log_wins_sc__net_profit_margin                         2688 non-null   float64
#  10  log_wins_sc__effective_tax_rate                        2688 non-null   float64
#  11  log_wins_sc__return_on_assets                          2688 non-null   float64
#  12  log_wins_sc__return_on_equity                          2688 non-null   float64
#  13  log_wins_sc__return_on_capital_employed                2688 non-null   float64
#  14  log_wins_sc__net_income_per_ebt                        2688 non-null   float64
#  15  log_wins_sc__ebt_per_ebit                              2688 non-null   float64
#  16  log_wins_sc__ebit_per_revenue                          2688 non-null   float64
#  17  log_wins_sc__debt_ratio                                2688 non-null   float64
#  18  log_wins_sc__debt_equity_ratio                         2688 non-null   float64
#  19  log_wins_sc__total_debt_to_capitalization              2688 non-null   float64
#  20  log_wins_sc__cash_flow_to_debt_ratio                   2688 non-null   float64
#  21  log_wins_sc__company_equity_multiplier                 2688 non-null   float64
#  22  log_wins_sc__receivables_turnover                      2688 non-null   float64
#  23  log_wins_sc__fixed_asset_turnover                      2688 non-null   float64
#  24  log_wins_sc__asset_turnover                            2688 non-null   float64
#  25  log_wins_sc__operating_cash_flow_per_share             2688 non-null   float64
#  26  log_wins_sc__free_cash_flow_per_share                  2688 non-null   float64
#  27  log_wins_sc__cash_per_share                            2688 non-null   float64
#  28  log_wins_sc__operating_cash_flow_sales_ratio           2688 non-null   float64
#  29  log_wins_sc__free_cash_flow_operating_cash_flow_ratio  2688 non-null   float64
#  30  log_wins_sc__cash_flow_coverage_ratios                 2688 non-null   float64
#  31  log_wins_sc__capital_expenditure_coverage_ratio        2688 non-null   float64
#  32  log_wins_sc__dividend_paid_and_capex_coverage_ratio    2688 non-null   float64
#  33  log_wins_sc__price_book_value_ratio                    2688 non-null   float64
#  34  log_wins_sc__price_to_book_ratio                       2688 non-null   float64
#  35  log_wins_sc__price_to_sales_ratio                      2688 non-null   float64
#  36  log_wins_sc__price_earnings_ratio                      2688 non-null   float64
#  37  log_wins_sc__price_to_free_cash_flows_ratio            2688 non-null   float64
#  38  log_wins_sc__price_to_operating_cash_flows_ratio       2688 non-null   float64
#  39  log_wins_sc__price_cash_flow_ratio                     2688 non-null   float64
#  40  log_wins_sc__price_earnings_to_growth_ratio            2688 non-null   float64
#  41  log_wins_sc__price_sales_ratio                         2688 non-null   float64
#  42  log_wins_sc__enterprise_value_multiple                 2688 non-null   float64
#  43  log_wins_sc__price_fair_value                          2688 non-null   float64
#  44  log_wins_sc__interest_coverage                         2688 non-null   float64
#  45  log_wins_sc__operating_cash_flow_per_share_growth      2688 non-null   float64
#  46  log_wins_sc__free_cash_flow_per_share_growth           2688 non-null   float64
#  47  log_wins_sc___payout_ratio                             2688 non-null   float64
#  48  log_wins_sc___dividend_payout_ratio                    2688 non-null   float64
#  49  log_wins_sc___dividend_yield                           2688 non-null   float64
#  50  ord__fiscal_year                                       2688 non-null   float64
# dtypes: float64(51)
# memory usage: 1.0 MB

# %%
train_prepared_df.describe()
# Out:
#        log_wins_sc__current_ratio  log_wins_sc__quick_ratio  \
# count                 2688.000000               2688.000000
# mean                     0.888600                  1.299083
# std                      2.571908                  3.995140
# min                     -0.642276                 -0.702830
# 25%                     -0.272358                 -0.311321
# 50%                      0.000000                  0.000000
# 75%                      0.727642                  0.688679
# max                     11.146341                 18.042453
#
#        log_wins_sc__cash_ratio  log_wins_sc__days_of_sales_outstanding  \
# count              2688.000000                             2688.000000
# mean                  0.807956                                0.273892
# std                   2.264931                                1.205556
# min                  -0.508621                               -1.050483
# 25%                  -0.293103                               -0.460809
# 50%                  -0.004310                                0.000000
# 75%                   0.706897                                0.539281
# max                   9.758621                                4.363889
#
#        log_wins_sc__operating_cycle  log_wins_sc__cash_conversion_cycle  \
# count                  2.688000e+03                        2.688000e+03
# mean                  -2.397558e+08                       -3.296199e+08
# std                    1.035505e+09                        1.423839e+09
# min                   -4.718981e+09                       -6.489735e+09
# 25%                   -4.129276e-01                       -4.348716e-01
# 50%                    0.000000e+00                        0.000000e+00
# 75%                    5.870591e-01                        5.651420e-01
# max                    3.626942e+00                        3.209408e+00
#
#        log_wins_sc__gross_profit_margin  log_wins_sc__operating_profit_margin  \
# count                       2688.000000                           2688.000000
# mean                           0.093808                              0.070933
# std                            0.651495                              0.908274
# min                           -0.929577                             -1.878788
# 25%                           -0.422535                             -0.484848
# 50%                            0.000000                              0.000000
# 75%                            0.577465                              0.522727
# max                            1.225352                              2.212121
#
#        log_wins_sc__pretax_profit_margin  log_wins_sc__net_profit_margin  ...  \
# count                        2688.000000                     2688.000000  ...
# mean                            0.062476                        0.076150  ...
# std                             0.889057                        0.899636  ...
# min                            -2.000000                       -2.153846  ...
# 25%                            -0.419355                       -0.423077  ...
# 50%                             0.000000                        0.019231  ...
# 75%                             0.580645                        0.576923  ...
# max                             2.064516                        2.076923  ...
#
#        log_wins_sc__price_sales_ratio  log_wins_sc__enterprise_value_multiple  \
# count                     2688.000000                             2688.000000
# mean                         0.355427                                0.106015
# std                          0.982906                                1.446543
# min                         -0.576224                               -3.869137
# 25%                         -0.337063                               -0.438204
# 50%                          0.000000                                0.000000
# 75%                          0.662238                                0.561679
# max                          3.232168                                4.070826
#
#        log_wins_sc__price_fair_value  log_wins_sc__interest_coverage  \
# count                    2688.000000                     2688.000000
# mean                        0.532750                        0.707768
# std                         1.511401                        2.152077
# min                        -1.517514                       -1.350297
# 25%                        -0.266667                       -0.324427
# 50%                        -0.000565                        0.000000
# 75%                         0.733333                        0.675785
# max                         5.796610                        8.704411
#
#        log_wins_sc__operating_cash_flow_per_share_growth  \
# count                                        2688.000000
# mean                                            0.051272
# std                                             1.661639
# min                                            -4.305556
# 25%                                            -0.458333
# 50%                                             0.000000
# 75%                                             0.541667
# max                                             4.708333
#
#        log_wins_sc__free_cash_flow_per_share_growth  \
# count                                   2688.000000
# mean                                       0.035133
# std                                        1.672271
# min                                       -3.975207
# 25%                                       -0.512397
# 50%                                        0.000000
# 75%                                        0.487603
# max                                        4.834711
#
#        log_wins_sc___payout_ratio  log_wins_sc___dividend_payout_ratio  \
# count                2.688000e+03                         2.688000e+03
# mean                 1.658492e-01                         1.658492e-01
# std                  7.527657e-01                         7.527657e-01
# min                 -5.180237e-01                        -5.180237e-01
# 25%                 -5.180237e-01                        -5.180237e-01
# 50%                  2.390727e-12                         2.390727e-12
# 75%                  4.819763e-01                         4.819763e-01
# max                  2.402389e+00                         2.402389e+00
#
#        log_wins_sc___dividend_yield  ord__fiscal_year
# count                   2688.000000       2688.000000
# mean                       0.184515          2.377232
# std                        0.667236          1.178439
# min                       -0.457785          0.000000
# 25%                       -0.457785          1.000000
# 50%                        0.000000          2.000000
# 75%                        0.542215          3.000000
# max                        1.961591          5.000000
#
# [8 rows x 51 columns]

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train_prepared_df['log_wins_sc__return_on_capital_employed'], bins=50, kde=True)
plt.title(f"Distribution {'return_on_capital_employed'}")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train_prepared_df['log_wins_sc__net_profit_margin'], bins=50, kde=True)
plt.title(f"Distribution {'net_profit_margin'}")
plt.show()

# %% [markdown]
# # Linear Models

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lin_reg = make_pipeline(preprocessing, LinearRegression())

# %%
from sklearn.model_selection import cross_val_score

lin_rmses = -cross_val_score(lin_reg, train, train_label,
                              scoring="neg_root_mean_squared_error", cv=10)

pd.Series(lin_rmses).describe()
# Out:
# count    1.000000e+01
# mean     3.930955e+11
# std      2.432598e+11
# min      3.928233e+05
# 25%      1.833557e+11
# 50%      4.569355e+11
# 75%      5.948160e+11
# max      7.012814e+11
# dtype: float64

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.linear_model import Ridge

ridge_reg = make_pipeline(preprocessing, Ridge(alpha=100, solver="cholesky"))

# %%
ridge_rmses = -cross_val_score(ridge_reg, train, train_label,
                              scoring="neg_root_mean_squared_error", cv=10)

pd.Series(ridge_rmses).describe()
# Out:
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.01977e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.21401e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.11094e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=9.86619e-21): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.08649e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.1247e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.15436e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.08224e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.05456e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# count    1.000000e+01
# mean     4.190908e+11
# std      2.044781e+11
# min      7.963039e+05
# 25%      2.926273e+11
# 50%      4.820480e+11
# 75%      5.347329e+11
# max      6.950631e+11
# dtype: float64

# %% [markdown]
# ## Lasso Regression

# %%
from sklearn.linear_model import Lasso

lasso_reg = make_pipeline(preprocessing, Lasso())

# %%
lasso_rmses = -cross_val_score(lasso_reg, train, train_label,
                              scoring="neg_root_mean_squared_error", cv=10)

pd.Series(ridge_rmses).describe()
# Out:
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.929e+02, tolerance: 3.859e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.990e+02, tolerance: 3.982e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.845e+02, tolerance: 3.695e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.999e+02, tolerance: 3.998e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.092e+02, tolerance: 4.185e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.099e+02, tolerance: 4.225e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.993e+02, tolerance: 3.988e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.993e+02, tolerance: 3.987e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.029e+02, tolerance: 4.061e-02
#   model = cd_fast.enet_coordinate_descent(
# count    1.000000e+01
# mean     4.190908e+11
# std      2.044781e+11
# min      7.963039e+05
# 25%      2.926273e+11
# 50%      4.820480e+11
# 75%      5.347329e+11
# max      6.950631e+11
# dtype: float64

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

rdf_reg = make_pipeline(preprocessing, RandomForestRegressor(min_samples_leaf=10, min_samples_split=15, max_depth=5, random_state=42))

# %%
rdf_rmses = -cross_val_score(rdf_reg, train, train_label,
                              scoring="neg_root_mean_squared_error", cv=10)

pd.Series(rdf_rmses).describe()
# Out:
# count    10.000000
# mean      0.589054
# std       0.069694
# min       0.477047
# 25%       0.560022
# 50%       0.568708
# 75%       0.626222
# max       0.727022
# dtype: float64

# %%
relative_rmse_rdf_reg = rdf_rmses.mean() / train_label.mean()
relative_rmse_rdf_reg.round(2)
# Out:
# 5.69

# %%
rdf_reg.fit(train, train_label)

rdf_model = rdf_reg.named_steps['randomforestregressor']
importances = rdf_model.feature_importances_

feature_names_out = preprocessing.get_feature_names_out()

# %%
feature_importance = pd.DataFrame({
    'Feature': feature_names_out,
    'Importance': importances
})

feature_importance = feature_importance.sort_values(by='Importance', ascending=False).reset_index(drop=True)

feature_importance
# Out:
#                                               Feature  Importance
# 0                                    ord__fiscal_year    0.225893
# 1                      log_wins_sc__net_profit_margin    0.078084
# 2                        log_wins_sc___dividend_yield    0.068650
# 3                   log_wins_sc__price_earnings_ratio    0.062922
# 4                      log_wins_sc__price_sales_ratio    0.041351
# 5   log_wins_sc__operating_cash_flow_per_share_growth    0.036445
# 6                      log_wins_sc__interest_coverage    0.029709
# 7                   log_wins_sc__price_to_sales_ratio    0.025864
# 8                       log_wins_sc__return_on_assets    0.023807
# 9         log_wins_sc__price_earnings_to_growth_ratio    0.020139
# 10                      log_wins_sc__return_on_equity    0.018615
# 11                  log_wins_sc__pretax_profit_margin    0.017517
# 12                log_wins_sc__price_book_value_ratio    0.016365
# 13             log_wins_sc__enterprise_value_multiple    0.016265
# 14                   log_wins_sc__price_to_book_ratio    0.015893
# 15  log_wins_sc__dividend_paid_and_capex_coverage_...    0.015716
# 16       log_wins_sc__free_cash_flow_per_share_growth    0.015578
# 17                 log_wins_sc__price_cash_flow_ratio    0.014813
# 18                      log_wins_sc__price_fair_value    0.014253
# 19   log_wins_sc__price_to_operating_cash_flows_ratio    0.012788
# 20             log_wins_sc__company_equity_multiplier    0.012525
# 21                        log_wins_sc__asset_turnover    0.012016
# 22                        log_wins_sc__cash_per_share    0.011756
# 23                    log_wins_sc__effective_tax_rate    0.011733
# 24            log_wins_sc__return_on_capital_employed    0.011671
# 25                    log_wins_sc__net_income_per_ebt    0.011572
# 26                  log_wins_sc__fixed_asset_turnover    0.011419
# 27                          log_wins_sc__ebt_per_ebit    0.011300
# 28             log_wins_sc__days_of_sales_outstanding    0.010681
# 29        log_wins_sc__price_to_free_cash_flows_ratio    0.008712
# 30                         log_wins_sc__current_ratio    0.008587
# 31         log_wins_sc__operating_cash_flow_per_share    0.008433
# 32  log_wins_sc__free_cash_flow_operating_cash_flo...    0.008237
# 33                   log_wins_sc__gross_profit_margin    0.008061
# 34                           log_wins_sc__quick_ratio    0.007987
# 35              log_wins_sc__free_cash_flow_per_share    0.007523
# 36    log_wins_sc__capital_expenditure_coverage_ratio    0.006752
# 37               log_wins_sc__cash_flow_to_debt_ratio    0.006416
# 38                            log_wins_sc__cash_ratio    0.006330
# 39       log_wins_sc__operating_cash_flow_sales_ratio    0.006080
# 40                 log_wins_sc__cash_conversion_cycle    0.005643
# 41                  log_wins_sc__receivables_turnover    0.005379
# 42                     log_wins_sc__debt_equity_ratio    0.005044
# 43             log_wins_sc__cash_flow_coverage_ratios    0.004977
# 44                            log_wins_sc__debt_ratio    0.004429
# 45                       log_wins_sc__operating_cycle    0.003915
# 46                      log_wins_sc__ebit_per_revenue    0.003596
# 47          log_wins_sc__total_debt_to_capitalization    0.003327
# 48               log_wins_sc__operating_profit_margin    0.002574
# 49                         log_wins_sc___payout_ratio    0.001841
# 50                log_wins_sc___dividend_payout_ratio    0.000818

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBRegressor

xgb_reg = make_pipeline(preprocessing, XGBRegressor(random_state=42))

# %%
xgb_rmses = -cross_val_score(xgb_reg, train, train_label,
                              scoring="neg_root_mean_squared_error", cv=10)

pd.Series(xgb_rmses).describe()
# Out:
# count    10.000000
# mean      0.887669
# std       0.563246
# min       0.498083
# 25%       0.652270
# 50%       0.680978
# 75%       0.748375
# max       2.405761
# dtype: float64

# %%
xgb_reg.fit(train, train_label)

xgb_model = xgb_reg.named_steps['xgbregressor']
importances = xgb_model.feature_importances_

feature_names_out = preprocessing.get_feature_names_out()

# %%
feature_importance = pd.DataFrame({
    'Feature': feature_names_out,
    'Importance': importances
})

feature_importance = feature_importance.sort_values(by='Importance', ascending=False).reset_index(drop=True)

feature_importance
# Out:
#                                               Feature  Importance
# 0                                    ord__fiscal_year    0.126341
# 1                      log_wins_sc__net_profit_margin    0.058791
# 2                        log_wins_sc___dividend_yield    0.055175
# 3                   log_wins_sc__price_to_sales_ratio    0.048880
# 4                   log_wins_sc__price_earnings_ratio    0.034861
# 5                 log_wins_sc__price_book_value_ratio    0.034604
# 6              log_wins_sc__company_equity_multiplier    0.028369
# 7                       log_wins_sc__return_on_assets    0.028165
# 8                   log_wins_sc__receivables_turnover    0.027344
# 9                     log_wins_sc__effective_tax_rate    0.023989
# 10            log_wins_sc__return_on_capital_employed    0.022130
# 11                    log_wins_sc__net_income_per_ebt    0.022099
# 12                          log_wins_sc__ebt_per_ebit    0.020564
# 13  log_wins_sc__operating_cash_flow_per_share_growth    0.020358
# 14    log_wins_sc__capital_expenditure_coverage_ratio    0.019597
# 15                      log_wins_sc__return_on_equity    0.019483
# 16                        log_wins_sc__asset_turnover    0.019137
# 17        log_wins_sc__price_earnings_to_growth_ratio    0.018877
# 18              log_wins_sc__free_cash_flow_per_share    0.018348
# 19                  log_wins_sc__pretax_profit_margin    0.018198
# 20                  log_wins_sc__fixed_asset_turnover    0.017591
# 21               log_wins_sc__operating_profit_margin    0.017027
# 22                     log_wins_sc__interest_coverage    0.016622
# 23   log_wins_sc__price_to_operating_cash_flows_ratio    0.016391
# 24                   log_wins_sc__gross_profit_margin    0.016285
# 25               log_wins_sc__cash_flow_to_debt_ratio    0.016250
# 26  log_wins_sc__dividend_paid_and_capex_coverage_...    0.015821
# 27       log_wins_sc__operating_cash_flow_sales_ratio    0.015809
# 28             log_wins_sc__enterprise_value_multiple    0.015642
# 29                        log_wins_sc__cash_per_share    0.014973
# 30                       log_wins_sc__operating_cycle    0.014283
# 31         log_wins_sc__operating_cash_flow_per_share    0.014009
# 32          log_wins_sc__total_debt_to_capitalization    0.013709
# 33                         log_wins_sc___payout_ratio    0.013671
# 34        log_wins_sc__price_to_free_cash_flows_ratio    0.013392
# 35  log_wins_sc__free_cash_flow_operating_cash_flo...    0.013319
# 36       log_wins_sc__free_cash_flow_per_share_growth    0.013219
# 37                 log_wins_sc__cash_conversion_cycle    0.013097
# 38                            log_wins_sc__cash_ratio    0.012964
# 39             log_wins_sc__days_of_sales_outstanding    0.012870
# 40                            log_wins_sc__debt_ratio    0.012140
# 41                     log_wins_sc__debt_equity_ratio    0.011912
# 42                           log_wins_sc__quick_ratio    0.010259
# 43                         log_wins_sc__current_ratio    0.003434
# 44                log_wins_sc___dividend_payout_ratio    0.000000
# 45             log_wins_sc__cash_flow_coverage_ratios    0.000000
# 46                      log_wins_sc__price_fair_value    0.000000
# 47                      log_wins_sc__ebit_per_revenue    0.000000
# 48                 log_wins_sc__price_cash_flow_ratio    0.000000
# 49                   log_wins_sc__price_to_book_ratio    0.000000
# 50                     log_wins_sc__price_sales_ratio    0.000000

# %% [markdown]
# # Simplifiyng the Data Set

# %%
ratios = [
    "net_profit_margin", "return_on_equity", "return_on_capital_employed",  # Profitability
    "asset_turnover",  # Eficciency
    "current_ratio", "debt_equity_ratio", "interest_coverage",  # Liquidity and Solvency
    "price_to_free_cash_flows_ratio", "price_earnings_ratio", "price_book_value_ratio",  # Valuation
    'operating_cash_flow_per_share_growth', 'free_cash_flow_per_share_growth','price_earnings_to_growth_ratio'  # Growth
] 

dividend_ratios = ['dividend_yield']

new_columns = ratios + dividend_ratios + ['fiscal_year']

# %%
train = train_set[new_columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import RobustScaler
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import FunctionTransformer


def preprocess_column(X):
    X_log = np.log1p(X - X.min() + 1)  
    X_wins = winsorize(X_log, limits=(0.04, 0.04), axis=0)  
    return np.array(X_wins)

ratio_pipeline = make_pipeline(KNNImputer(n_neighbors=5) ,FunctionTransformer(preprocess_column, feature_names_out="one-to-one"), 
                               RobustScaler())

dividend_pipeline = make_pipeline(SimpleImputer(strategy='constant', fill_value=0) ,FunctionTransformer(preprocess_column, feature_names_out="one-to-one"), 
                               RobustScaler())

ord_pipeline = make_pipeline(ordinal_encoder) 

preprocessing = ColumnTransformer([
        ("log_wins_sc", ratio_pipeline, ratios),
        ("log_wins_sc_", dividend_pipeline, dividend_ratios),
        ("ord", ord_pipeline, ['fiscal_year']),
    ],
    remainder='passthrough')

# %%
train_prepared = preprocessing.fit_transform(train)
train_prepared.shape
# Out:
# (2688, 15)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lin_reg = make_pipeline(preprocessing, LinearRegression())

# %%
from sklearn.model_selection import cross_val_score

lin_rmses = -cross_val_score(lin_reg, train, train_label,
                              scoring="neg_root_mean_squared_error", cv=10)

pd.Series(lin_rmses).describe()
# Out:
# count        10.000000
# mean     213013.441712
# std      147707.179335
# min       34863.242558
# 25%      109462.904844
# 50%      213455.320328
# 75%      224551.492584
# max      469111.336805
# dtype: float64

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

rdf_reg = make_pipeline(preprocessing, RandomForestRegressor(min_samples_leaf=10, min_samples_split=15, max_depth=5, random_state=42))

# %%
rdf_rmses = -cross_val_score(rdf_reg, train, train_label,
                              scoring="neg_root_mean_squared_error", cv=10)

pd.Series(rdf_rmses).describe()
# Out:
# count    10.000000
# mean      0.432326
# std       0.049081
# min       0.362763
# 25%       0.406427
# 50%       0.423581
# 75%       0.457228
# max       0.537512
# dtype: float64

# %%
rdf_reg.fit(train, train_label)
y_pred_rdf = rdf_reg.predict(train)

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=train_label, y=y_pred_rdf, color='#A3D9A5', alpha=0.9)
sns.lineplot(x=[min(train_label), max(train_label)], 
             y=[min(train_label), max(train_label)], 
             color='#2E2E2E', linestyle='--')
plt.xlabel('Real Returns')
plt.ylabel('Predicted Returns')
plt.title('Real vs Predicted Returns')
plt.show()
