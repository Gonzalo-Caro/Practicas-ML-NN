# %% [markdown]
# # Import the Data

# %%
import pandas as pd

df = pd.read_csv("data/stocks.csv")

# %%
df.head()
# Out:
#   Stock    return  adjusted_price  close_price period_ending fiscal_period  \
# 0     A  0.538447      157.059998   157.059998    2021-10-31            FY
# 1     A -0.119126      138.350006   138.350006    2022-10-31            FY
# 2     A -0.252837      103.370003   103.370003    2023-10-31            FY
# 3     A  0.260617      130.309998   130.309998    2024-10-31            FY
# 4  AAPL  0.308514      146.919998   146.919998    2021-09-25            FY
#
#    fiscal_year  current_ratio  quick_ratio  cash_ratio  ...  \
# 0         2021       2.224239     1.738290    0.868852  ...
# 1         2022       2.030091     1.472327    0.565825  ...
# 2         2023       2.611354     1.968185    0.991890  ...
# 3         2024       2.089182     1.576253    0.701319  ...
# 4         2021       1.074553     1.022115    0.278449  ...
#
#    price_earnings_ratio  price_to_free_cash_flows_ratio  \
# 0             39.459702                       36.841235
# 1             32.987759                       40.515818
# 2             24.508694                       20.617897
# 3             29.317223                       27.523598
# 4             25.916254                       26.397759
#
#    price_to_operating_cash_flows_ratio  price_cash_flow_ratio  \
# 0                            32.152350              32.152350
# 1                            31.529459              31.529459
# 2                            17.150553              17.150553
# 3                            21.581896              21.581896
# 4                            23.585141              23.585141
#
#    price_earnings_to_growth_ratio  price_sales_ratio  dividend_yield  \
# 0                        0.557219           7.555980        0.004943
# 1                        6.251966           6.040691        0.006044
# 2                       34.230475           4.447648        0.008720
# 3                        5.623576           5.804900        0.007251
# 4                        0.363486           6.707591        0.005896
#
#    enterprise_value_multiple  price_fair_value  interest_coverage
# 0                  28.400719          8.859944          16.629630
# 1                  21.606143          7.797672          19.261905
# 2                  18.517780          5.199449          14.210526
# 3                  26.781519          6.407240          15.500000
# 4                  21.253174         38.892865          41.190548
#
# [5 rows x 61 columns]

# %%
df.shape
# Out:
# (3357, 61)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3357 entries, 0 to 3356
# Data columns (total 61 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Stock                                     3357 non-null   object
#  1   return                                    3357 non-null   float64
#  2   adjusted_price                            3357 non-null   float64
#  3   close_price                               3357 non-null   float64
#  4   period_ending                             3357 non-null   object
#  5   fiscal_period                             3357 non-null   object
#  6   fiscal_year                               3357 non-null   int64
#  7   current_ratio                             3269 non-null   float64
#  8   quick_ratio                               3269 non-null   float64
#  9   cash_ratio                                3258 non-null   float64
#  10  days_of_sales_outstanding                 3042 non-null   float64
#  11  days_of_inventory_outstanding             2491 non-null   float64
#  12  operating_cycle                           3122 non-null   float64
#  13  days_of_payables_outstanding              2919 non-null   float64
#  14  cash_conversion_cycle                     3166 non-null   float64
#  15  gross_profit_margin                       3326 non-null   float64
#  16  operating_profit_margin                   3265 non-null   float64
#  17  pretax_profit_margin                      3337 non-null   float64
#  18  net_profit_margin                         3337 non-null   float64
#  19  effective_tax_rate                        3328 non-null   float64
#  20  return_on_assets                          3330 non-null   float64
#  21  return_on_equity                          3330 non-null   float64
#  22  return_on_capital_employed                3260 non-null   float64
#  23  net_income_per_ebt                        3348 non-null   float64
#  24  ebt_per_ebit                              3276 non-null   float64
#  25  ebit_per_revenue                          3265 non-null   float64
#  26  debt_ratio                                3296 non-null   float64
#  27  debt_equity_ratio                         3293 non-null   float64
#  28  long_term_debt_to_capitalization          2981 non-null   float64
#  29  total_debt_to_capitalization              3296 non-null   float64
#  30  cash_flow_to_debt_ratio                   3283 non-null   float64
#  31  company_equity_multiplier                 3332 non-null   float64
#  32  receivables_turnover                      3042 non-null   float64
#  33  payables_turnover                         2919 non-null   float64
#  34  inventory_turnover                        2491 non-null   float64
#  35  fixed_asset_turnover                      3252 non-null   float64
#  36  asset_turnover                            3321 non-null   float64
#  37  operating_cash_flow_per_share             3331 non-null   float64
#  38  free_cash_flow_per_share                  3332 non-null   float64
#  39  cash_per_share                            3316 non-null   float64
#  40  payout_ratio                              2515 non-null   float64
#  41  operating_cash_flow_sales_ratio           3326 non-null   float64
#  42  free_cash_flow_operating_cash_flow_ratio  3339 non-null   float64
#  43  cash_flow_coverage_ratios                 3283 non-null   float64
#  44  short_term_coverage_ratios                2560 non-null   float64
#  45  capital_expenditure_coverage_ratio        3140 non-null   float64
#  46  dividend_paid_and_capex_coverage_ratio    3313 non-null   float64
#  47  dividend_payout_ratio                     2515 non-null   float64
#  48  price_book_value_ratio                    3327 non-null   float64
#  49  price_to_book_ratio                       3327 non-null   float64
#  50  price_to_sales_ratio                      3330 non-null   float64
#  51  price_earnings_ratio                      3341 non-null   float64
#  52  price_to_free_cash_flows_ratio            3332 non-null   float64
#  53  price_to_operating_cash_flows_ratio       3331 non-null   float64
#  54  price_cash_flow_ratio                     3331 non-null   float64
#  55  price_earnings_to_growth_ratio            3321 non-null   float64
#  56  price_sales_ratio                         3330 non-null   float64
#  57  dividend_yield                            2510 non-null   float64
#  58  enterprise_value_multiple                 3219 non-null   float64
#  59  price_fair_value                          3327 non-null   float64
#  60  interest_coverage                         3042 non-null   float64
# dtypes: float64(57), int64(1), object(3)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#             return  adjusted_price  close_price  fiscal_year  current_ratio  \
# count  3357.000000     3357.000000  3357.000000  3357.000000   3.269000e+03
# mean      0.254881      144.149912   146.098588  2022.379506   2.218784e+03
# std       1.609133      318.167095   318.060520     1.180961   1.261828e+05
# min      -0.979550        0.351800     0.904000  2020.000000  -1.207344e+00
# 25%      -0.089162       32.860001    35.660000  2021.000000   9.526310e-01
# 50%       0.104446       74.690002    75.849998  2022.000000   1.354000e+00
# 75%       0.338095      163.425915   164.020004  2023.000000   2.320073e+00
# max      66.156697     8178.899902  8178.899902  2025.000000   7.214525e+06
#
#         quick_ratio    cash_ratio  days_of_sales_outstanding  \
# count  3.269000e+03  3.258000e+03                3042.000000
# mean   4.879385e+03  1.444117e+03                 406.531021
# std    2.057431e+05  5.912035e+04               16553.772517
# min   -2.143429e+01 -1.941784e+00               -1026.237212
# 25%    7.228859e-01  1.621525e-01                  33.256940
# 50%    1.085292e+00  3.662762e-01                  55.705076
# 75%    1.863554e+00  8.047852e-01                  80.929588
# max    1.039021e+07  2.783903e+06              911492.030060
#
#        days_of_inventory_outstanding  operating_cycle  ...  \
# count                   2.491000e+03     3.122000e+03  ...
# mean                   -8.974852e+08    -7.160904e+08  ...
# std                     3.236016e+10     2.890661e+10  ...
# min                    -1.352819e+12    -1.352819e+12  ...
# 25%                     1.968370e+01     6.058160e+01  ...
# 50%                     5.949163e+01     1.059591e+02  ...
# 75%                     1.095019e+02     1.738482e+02  ...
# max                     8.687000e+04     9.114920e+05  ...
#
#        price_earnings_ratio  price_to_free_cash_flows_ratio  \
# count           3341.000000                     3332.000000
# mean              44.567515                       -0.627078
# std             1352.300134                     1295.499141
# min           -50860.861063                   -64422.616579
# 25%               10.076951                        7.308444
# 50%               19.534143                       18.673788
# 75%               32.247395                       32.374021
# max            41044.843398                    20532.021081
#
#        price_to_operating_cash_flows_ratio  price_cash_flow_ratio  \
# count                          3331.000000            3331.000000
# mean                              3.030877               3.030877
# std                            1203.793645            1203.793645
# min                          -64422.616579          -64422.616579
# 25%                               6.982197               6.982197
# 50%                              14.287013              14.287013
# 75%                              24.074604              24.074604
# max                           17341.881818           17341.881818
#
#        price_earnings_to_growth_ratio  price_sales_ratio  dividend_yield  \
# count                     3321.000000        3330.000000     2510.000000
# mean                        -0.116693          12.608792        0.050253
# std                         19.604428         366.414420        0.975755
# min                       -410.657310         -68.940568        0.000003
# 25%                         -0.517442           1.482062        0.011356
# 50%                          0.139026           2.863082        0.021469
# 75%                          0.982282           5.623189        0.036593
# max                        508.437227       20992.687770       48.781099
#
#        enterprise_value_multiple  price_fair_value  interest_coverage
# count                3219.000000       3327.000000        3042.000000
# mean                  -25.473482          8.790017         -39.011577
# std                  2584.680301        621.800273        3656.757029
# min               -137035.779167     -20613.985237     -176158.000000
# 25%                     7.728815          1.560106           2.582171
# 50%                    13.467717          3.012962           6.780716
# 75%                    20.609821          6.746772          15.913089
# max                 40665.587360      26229.799716       12159.422535
#
# [8 rows x 58 columns]

# %%
df.columns
# Out:
# Index(['Stock', 'return', 'adjusted_price', 'close_price', 'period_ending',
#        'fiscal_period', 'fiscal_year', 'current_ratio', 'quick_ratio',
#        'cash_ratio', 'days_of_sales_outstanding',
#        'days_of_inventory_outstanding', 'operating_cycle',
#        'days_of_payables_outstanding', 'cash_conversion_cycle',
#        'gross_profit_margin', 'operating_profit_margin',
#        'pretax_profit_margin', 'net_profit_margin', 'effective_tax_rate',
#        'return_on_assets', 'return_on_equity', 'return_on_capital_employed',
#        'net_income_per_ebt', 'ebt_per_ebit', 'ebit_per_revenue', 'debt_ratio',
#        'debt_equity_ratio', 'long_term_debt_to_capitalization',
#        'total_debt_to_capitalization', 'cash_flow_to_debt_ratio',
#        'company_equity_multiplier', 'receivables_turnover',
#        'payables_turnover', 'inventory_turnover', 'fixed_asset_turnover',
#        'asset_turnover', 'operating_cash_flow_per_share',
#        'free_cash_flow_per_share', 'cash_per_share', 'payout_ratio',
#        'operating_cash_flow_sales_ratio',
#        'free_cash_flow_operating_cash_flow_ratio', 'cash_flow_coverage_ratios',
#        'short_term_coverage_ratios', 'capital_expenditure_coverage_ratio',
#        'dividend_paid_and_capex_coverage_ratio', 'dividend_payout_ratio',
#        'price_book_value_ratio', 'price_to_book_ratio', 'price_to_sales_ratio',
#        'price_earnings_ratio', 'price_to_free_cash_flows_ratio',
#        'price_to_operating_cash_flows_ratio', 'price_cash_flow_ratio',
#        'price_earnings_to_growth_ratio', 'price_sales_ratio', 'dividend_yield',
#        'enterprise_value_multiple', 'price_fair_value', 'interest_coverage'],
#       dtype='object')

# %%
def growth (df, col_ratios):

    df = df.sort_values(by=["Stock", "fiscal_year"]).copy()
    df[col_ratios] = df.groupby("Stock")[col_ratios].transform(lambda x: x.fillna(x.mean()))

    def anual_growth (group):
        return group[col_ratios].pct_change(fill_method=None)
    
    df_gr = df.groupby("Stock", group_keys=False).apply(anual_growth )
    df_gr = df_gr.add_suffix("_growth")
    df_gr = df_gr.groupby(df['Stock']).transform(lambda x: x.fillna(x.mean()))
    df = pd.concat([df, df_gr], axis=1)

    return df

# %%
growth_ratios = ['operating_cash_flow_per_share', 'free_cash_flow_per_share']

df = growth (df, growth_ratios)
df.head()
# Out:
# /var/folders/n8/s5gn3hhs4z90dmrnk47r93fh0000gn/T/ipykernel_2962/2541788003.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_gr = df.groupby("Stock", group_keys=False).apply(anual_growth )
#   Stock    return  adjusted_price  close_price period_ending fiscal_period  \
# 0     A  0.538447      157.059998   157.059998    2021-10-31            FY
# 1     A -0.119126      138.350006   138.350006    2022-10-31            FY
# 2     A -0.252837      103.370003   103.370003    2023-10-31            FY
# 3     A  0.260617      130.309998   130.309998    2024-10-31            FY
# 4  AAPL  0.308514      146.919998   146.919998    2021-09-25            FY
#
#    fiscal_year  current_ratio  quick_ratio  cash_ratio  ...  \
# 0         2021       2.224239     1.738290    0.868852  ...
# 1         2022       2.030091     1.472327    0.565825  ...
# 2         2023       2.611354     1.968185    0.991890  ...
# 3         2024       2.089182     1.576253    0.701319  ...
# 4         2021       1.074553     1.022115    0.278449  ...
#
#    price_to_operating_cash_flows_ratio  price_cash_flow_ratio  \
# 0                            32.152350              32.152350
# 1                            31.529459              31.529459
# 2                            17.150553              17.150553
# 3                            21.581896              21.581896
# 4                            23.585141              23.585141
#
#    price_earnings_to_growth_ratio  price_sales_ratio  dividend_yield  \
# 0                        0.557219           7.555980        0.004943
# 1                        6.251966           6.040691        0.006044
# 2                       34.230475           4.447648        0.008720
# 3                        5.623576           5.804900        0.007251
# 4                        0.363486           6.707591        0.005896
#
#    enterprise_value_multiple  price_fair_value  interest_coverage  \
# 0                  28.400719          8.859944          16.629630
# 1                  21.606143          7.797672          19.261905
# 2                  18.517780          5.199449          14.210526
# 3                  26.781519          6.407240          15.500000
# 4                  21.253174         38.892865          41.190548
#
#    operating_cash_flow_per_share_growth  free_cash_flow_per_share_growth
# 0                              0.091211                         0.071182
# 1                             -0.101724                        -0.199017
# 2                              0.373579                         0.468235
# 3                              0.001779                        -0.055673
# 4                              0.079666                         0.092097
#
# [5 rows x 63 columns]

# %%
ratios = [
    "gross_profit_margin", "operating_profit_margin", "net_profit_margin", "return_on_equity", "return_on_capital_employed",  # Profitability
    "asset_turnover", "inventory_turnover", "receivables_turnover", "operating_cycle",  # Eficciency
    "current_ratio", "quick_ratio", "debt_equity_ratio", "capital_expenditure_coverage_ratio",  # Liquidity and Solvency
    "price_to_free_cash_flows_ratio", "price_earnings_ratio", "price_to_book_ratio", "price_fair_value",  # Valuation
    'operating_cash_flow_per_share_growth', 'free_cash_flow_per_share_growth','price_earnings_to_growth_ratio'  # Growth
]

# %%
import matplotlib.pyplot as plt

plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

df_ratios = df[ratios]
df_ratios.hist(bins=50, figsize=(15,12))

plt.show()

# %% [markdown]
# # Create a Test Set

# %%
import numpy as np

df["return_cat"] = pd.cut(df["return"],
                               bins = [-np.inf, -0.09, 0.10, 0.34, 1.6, np.inf],
                               labels = ['Very Low', 'Low', 'Medium', 'High', 'Very High'])

# %%
plt.figure(figsize=(8, 4))

df["return_cat"].value_counts().sort_index().plot.bar(rot=0, grid=False)
plt.xlabel("Return category")
plt.ylabel("Number of companies")

plt.show()

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(df, stratify=df['return_cat'], test_size=0.2, random_state=42)

# %%
def income_cat_proportions(data):
    return data["return_cat"].value_counts() / len(data)

compare_props = pd.DataFrame({
    "Overall %": income_cat_proportions(df),
    "Stratified %": income_cat_proportions(test_set),
}).sort_index()

(compare_props * 100).round(2)
# Out:
#             Overall %  Stratified %
# return_cat
# Very Low        24.87         24.85
# Low             24.52         24.55
# Medium          25.74         25.74
# High            22.64         22.62
# Very High        2.23          2.23

# %%
for set_ in (train_set, test_set):
    set_.drop("return_cat", axis=1, inplace=True)

# %%
train_df = df[df["fiscal_year"] < 2024] 
test_df = df[df["fiscal_year"] == 2024]  

print(f'Train set size:{train_df.shape}, Test set size: {test_df.shape}')
# Out:
# Train set size:(2620, 64), Test set size: (721, 64)

# %% [markdown]
# # Discover and Visualize the Data

# %%
stocks = train_set.copy()

# %%
profitability = ["gross_profit_margin", "operating_profit_margin", "return_on_capital_employed", "return"]
efficiency = ["asset_turnover", "inventory_turnover", "receivables_turnover", "operating_cycle", "return"]
liquidity_solvency = ["current_ratio", "quick_ratio", "debt_equity_ratio", "interest_coverage", "return"]
valuation = ["price_to_free_cash_flows_ratio", "price_earnings_ratio", "price_to_book_ratio", "return"]
growth = ["operating_cash_flow_per_share_growth", "free_cash_flow_per_share_growth", "price_earnings_to_growth_ratio", "return"]

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(stocks[profitability], figsize=(10, 6))
plt.show()

# %%
stocks_clean = stocks.copy()
for col in ratios:
    Q1 = stocks_clean[col].quantile(0.25)
    Q3 = stocks_clean[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    stocks_clean = stocks_clean[(stocks_clean[col] >= lower_bound) & (stocks_clean[col] <= upper_bound)]

# %%
scatter_matrix(stocks_clean[profitability], figsize=(10, 6))
plt.show()

# %%
scatter_matrix(stocks_clean[efficiency], figsize=(10, 6))
plt.show()

# %%
scatter_matrix(stocks_clean[liquidity_solvency], figsize=(10, 6))
plt.show()

# %%
scatter_matrix(stocks_clean[valuation], figsize=(10, 6))
plt.show()

# %%
scatter_matrix(stocks_clean[growth], figsize=(10, 6))
plt.show()

# %%
import seaborn as sns

ratios_r = ratios + ["return"]

correlation_matrix = stocks[ratios_r].corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="viridis", fmt=".2f", 
            linewidths=0.5, annot_kws={"size": 10}, vmax=1, vmin=-1)

plt.xticks(rotation=45, fontsize=9)
plt.yticks(rotation=0, fontsize=9)

plt.title('Heatmap: Correlation Matrix')
plt.show()

# %%
correlation_matrix = stocks_clean[ratios_r].corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="viridis", fmt=".2f", 
            linewidths=0.5, annot_kws={"size": 10}, vmax=1, vmin=-1)

plt.xticks(rotation=45, fontsize=9)
plt.yticks(rotation=0, fontsize=9)

plt.title('Heatmap: Correlation Matrix')
plt.show()

# %% [markdown]
# # Prepara the Data

# %%
train = train_set.drop("return", axis=1)
train_label = train_set[["return"]].copy()

# %%
outliers_dict = {}

for column in ratios:
    Q1 = train[column].quantile(0.25)
    Q3 = train[column].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    
    outliers = train[(train[column] < lower_bound) | (train[column] > upper_bound)]
    
    outliers_dict[column] = outliers

    print(f"Outliers in {column}: {outliers.shape[0]} outliers found.")
# Out:
# Outliers in gross_profit_margin: 27 outliers found.
# Outliers in operating_profit_margin: 224 outliers found.
# Outliers in net_profit_margin: 239 outliers found.
# Outliers in return_on_equity: 364 outliers found.
# Outliers in return_on_capital_employed: 186 outliers found.
# Outliers in asset_turnover: 174 outliers found.
# Outliers in inventory_turnover: 283 outliers found.
# Outliers in receivables_turnover: 302 outliers found.
# Outliers in operating_cycle: 240 outliers found.
# Outliers in current_ratio: 284 outliers found.
# Outliers in quick_ratio: 328 outliers found.
# Outliers in debt_equity_ratio: 310 outliers found.
# Outliers in capital_expenditure_coverage_ratio: 351 outliers found.
# Outliers in price_to_free_cash_flows_ratio: 380 outliers found.
# Outliers in price_earnings_ratio: 404 outliers found.
# Outliers in price_to_book_ratio: 361 outliers found.
# Outliers in price_fair_value: 361 outliers found.
# Outliers in operating_cash_flow_per_share_growth: 441 outliers found.
# Outliers in free_cash_flow_per_share_growth: 464 outliers found.
# Outliers in price_earnings_to_growth_ratio: 489 outliers found.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
sns.histplot(train['return_on_capital_employed'], bins=50, kde=True)
plt.title(f"Distribution {'return_on_capital_employed'}")
plt.show()

# %%
train["return_on_capital_employed_log"] = np.log1p(train["return_on_capital_employed"] - train["return_on_capital_employed"].min() + 1)

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['return_on_capital_employed_log'], bins=50, kde=True)
plt.title(f"Distribution {'return_on_capital_employed_log'}")
plt.show()

# %%
train["return_on_capital_employed_log"].describe()
# Out:
# count    2607.000000
# mean        3.664154
# std         0.058932
# min         0.693147
# 25%         3.663481
# 50%         3.664898
# 75%         3.666996
# max         3.829003
# Name: return_on_capital_employed_log, dtype: float64

# %%
from scipy.stats.mstats import winsorize

train["return_on_capital_employed_wins"] = winsorize(train["return_on_capital_employed_log"], limits=[0.01, 0.01])

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['return_on_capital_employed_wins'], bins=50, kde=True)
plt.title(f"Distribution {'return_on_capital_employed_wins'}")
plt.show()

# %%
train["return_on_capital_employed_wins"].describe()
# Out:
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/numpy/lib/function_base.py:4824: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# count    2607.000000
# mean        3.665521
# std         0.005762
# min         3.653361
# 25%         3.663481
# 50%         3.664898
# 75%         3.666996
# max         3.829003
# Name: return_on_capital_employed_wins, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
train['return_on_capital_employed_scaled'] = scaler.fit_transform(train[['return_on_capital_employed_wins']])

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['return_on_capital_employed_scaled'], bins=50, kde=True)
plt.title(f"Distribution {'return_on_capital_employed_scaled'}")
plt.show()

# %%
from sklearn.preprocessing import RobustScaler

def preprocess_column(df, columns, winsor_limits=(0.04, 0.04)):
    scaler = RobustScaler()
    
    for column in columns:
    
        df[f"{column}_log"] = np.log1p(df[column] - df[column].min() + 1)
        
        df[f"{column}_wins"] = winsorize(df[f"{column}_log"], limits=winsor_limits)
        
        df[f"{column}_scaled"] = scaler.fit_transform(df[[f"{column}_wins"]])

    return df

# %%
train = preprocess_column(train, ratios)

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['return_on_capital_employed_scaled'], bins=50, kde=True)
plt.title(f"Distribution {'return_on_capital_employed_scaled'}")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['price_earnings_ratio_scaled'], bins=50, kde=True)
plt.title(f"Distribution {'price_earnings_ratio_scaled'}")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['capital_expenditure_coverage_ratio_scaled'], bins=50, kde=True)
plt.title(f"Distribution {'capital_expenditure_coverage_ratio_scaled'}")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['net_profit_margin_scaled'], bins=50, kde=True)
plt.title(f"Distribution {'net_profit_margin_scaled'}")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['operating_cycle_scaled'], bins=50, kde=True)
plt.title(f"Distribution {'operating_cycle_scaled'}")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['return_on_equity_scaled'], bins=50, kde=True)
plt.title(f"Distribution {'return_on_equity_scaled'}")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['price_fair_value_scaled'], bins=50, kde=True)
plt.title(f"Distribution {'price_fair_value_scaled'}")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['free_cash_flow_per_share_growth_scaled'], bins=50, kde=True)
plt.title(f"Distribution {'free_cash_flow_per_share_growth_scaled'}")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train['debt_equity_ratio_scaled'], bins=50, kde=True)
plt.title(f"Distribution {'debt_equity_ratio_scaled'}")
plt.show()

# %%
train_label["log_return"] = np.log1p(train_label["return"])  # log1p(x) = log(1 + x)

plt.figure(figsize=(8, 5))

fig, axes = plt.subplots(1, 2, figsize=(14, 5))  

sns.histplot(train_label["return"], bins=50, kde=True, ax=axes[0], color="blue")
axes[0].set_title("Histogram of Return")
axes[0].set_xlabel("Return")
axes[0].set_ylabel("Frequency")

sns.histplot(train_label["log_return"], bins=50, kde=True, ax=axes[1], color="#2E2E2E")
axes[1].set_title("Histogram of Log(1 + Return)")
axes[1].set_xlabel("Log(1 + Return)")
axes[1].set_ylabel("Frequency")


plt.tight_layout()
plt.show()

# %%
missing_values_percent = train.isnull().sum() / len(train) * 100

missing_values_percent[missing_values_percent > 20]
# Out:
# days_of_inventory_outstanding    26.219739
# inventory_turnover               26.219739
# payout_ratio                     25.512104
# short_term_coverage_ratios       23.798883
# dividend_payout_ratio            25.512104
# dividend_yield                   25.698324
# inventory_turnover_log           26.219739
# inventory_turnover_wins          26.219739
# inventory_turnover_scaled        26.219739
# dtype: float64

# %%
from sklearn.impute import SimpleImputer

columns = ['payout_ratio', 'dividend_payout_ratio', 'dividend_yield']

imputer = SimpleImputer(strategy="constant", fill_value=0)
train[columns] = imputer.fit_transform(train[columns])

train[columns].isnull().sum()
# Out:
# payout_ratio             0
# dividend_payout_ratio    0
# dividend_yield           0
# dtype: int64

# %%
train = train.drop(["days_of_inventory_outstanding", 'inventory_turnover', 'short_term_coverage_ratios',
                    'days_of_payables_outstanding', 'payables_turnover', 'long_term_debt_to_capitalization'], axis=1)

# %%
missing_values_percent = train.isnull().sum() / len(train) * 100

missing_values_percent[missing_values_percent > 0]
# Out:
# current_ratio                               2.569832
# quick_ratio                                 2.569832
# cash_ratio                                  2.867784
# days_of_sales_outstanding                   9.348231
# operating_cycle                             6.964618
#                                               ...
# price_to_book_ratio_log                     1.005587
# price_fair_value_log                        1.005587
# operating_cash_flow_per_share_growth_log    0.260708
# free_cash_flow_per_share_growth_log         0.260708
# price_earnings_to_growth_ratio_log          1.005587
# Length: 75, dtype: float64

# %%
from sklearn.impute import KNNImputer

numeric_columns = train.select_dtypes(include=[np.number]).columns

knn_imputer = KNNImputer(n_neighbors=5)

train[numeric_columns] = knn_imputer.fit_transform(train[numeric_columns])

# %%
train.isnull().sum().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import OrdinalEncoder

unique_years = sorted(train["fiscal_year"].unique())
ordinal_encoder = OrdinalEncoder(categories=[unique_years])

# %%
train[['fiscal_year']] = ordinal_encoder.fit_transform(train[['fiscal_year']])

train[['fiscal_year']].head()
# Out:
#       fiscal_year
# 99            4.0
# 1274          1.0
# 2435          3.0
# 1695          2.0
# 3037          2.0

# %% [markdown]
# ## Transformation Pipeline

# %%
train = train_set.drop(['return'], axis=1)
train_label = train_label["log_return"].copy()

# %%
excluded_cols = ['Stock', 'adjusted_price', 'close_price', 'period_ending', 'fiscal_period',"days_of_inventory_outstanding", 'inventory_turnover', 'short_term_coverage_ratios',
                    'days_of_payables_outstanding', 'payables_turnover', 'long_term_debt_to_capitalization']

dividend_ratios = ['payout_ratio', 'dividend_payout_ratio', 'dividend_yield']

excluded_cols_2 = excluded_cols + dividend_ratios + ['fiscal_year']

ratios = [col for col in train.columns if col not in excluded_cols_2]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import RobustScaler
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import FunctionTransformer


def preprocess_column(X):
    X_log = np.log1p(X - X.min() + 1)  
    X_wins = winsorize(X_log, limits=(0.04, 0.04), axis=0)  
    return np.array(X_wins)

ratio_pipeline = make_pipeline(KNNImputer(n_neighbors=5) ,FunctionTransformer(preprocess_column, feature_names_out="one-to-one"), 
                               RobustScaler())

dividend_pipeline = make_pipeline(SimpleImputer(strategy='constant', fill_value=0) ,FunctionTransformer(preprocess_column, feature_names_out="one-to-one"), 
                               RobustScaler())

ord_pipeline = make_pipeline(ordinal_encoder) 

preprocessing = ColumnTransformer([
        ("log_wins_sc", ratio_pipeline, ratios),
        ("log_wins_sc_", dividend_pipeline, dividend_ratios),
        ("ord", ord_pipeline, ['fiscal_year']),
        ("drop_cols", "drop", excluded_cols)
    ],
    remainder='passthrough')

# %%
train_prepared = preprocessing.fit_transform(train)
train_prepared.shape
# Out:
# (2685, 51)

# %%
feature_names = preprocessing.get_feature_names_out()

train_prepared_df = pd.DataFrame(train_prepared, columns=feature_names)

train_prepared_df.head()
# Out:
#    log_wins_sc__current_ratio  log_wins_sc__quick_ratio  \
# 0                   -0.093496                  0.089202
# 1                   -0.231707                 -0.300469
# 2                    0.264228                  0.169014
# 3                   -0.373984                 -0.258216
# 4                   -0.223577                 -0.122066
#
#    log_wins_sc__cash_ratio  log_wins_sc__days_of_sales_outstanding  \
# 0                -0.194690                                0.222030
# 1                -0.442478                                0.478342
# 2                 0.176991                                1.127104
# 3                -0.212389                               -0.167574
# 4                 0.150442                               -0.511262
#
#    log_wins_sc__operating_cycle  log_wins_sc__cash_conversion_cycle  \
# 0                     -0.299219                           -0.052884
# 1                      0.400286                            0.139570
# 2                      1.079792                            0.639461
# 3                     -0.396919                           -0.695071
# 4                     -0.491608                           -0.110948
#
#    log_wins_sc__gross_profit_margin  log_wins_sc__operating_profit_margin  \
# 0                          0.253521                             -0.181818
# 1                         -0.197183                             -0.030303
# 2                          0.028169                              0.545455
# 3                          0.112676                              0.363636
# 4                         -0.253521                             -1.151515
#
#    log_wins_sc__pretax_profit_margin  log_wins_sc__net_profit_margin  ...  \
# 0                           0.000000                            0.04  ...
# 1                           0.096774                            0.04  ...
# 2                           0.645161                            0.60  ...
# 3                           0.225806                            0.16  ...
# 4                          -2.096774                           -2.32  ...
#
#    log_wins_sc__price_sales_ratio  log_wins_sc__enterprise_value_multiple  \
# 0                        0.174402                                0.117729
# 1                       -0.324895                               -0.438135
# 2                        1.526020                                0.902585
# 3                       -0.154712                               -0.397969
# 4                       -0.329114                               -1.596953
#
#    log_wins_sc__price_fair_value  log_wins_sc__interest_coverage  \
# 0                      -0.030635                        0.851717
# 1                      -0.278993                        4.312323
# 2                       2.788840                        6.928485
# 3                       0.028446                       -0.100606
# 4                       0.655361                       -0.728081
#
#    log_wins_sc__operating_cash_flow_per_share_growth  \
# 0                                           0.164384
# 1                                           0.027397
# 2                                           0.397260
# 3                                          -0.068493
# 4                                          -4.835616
#
#    log_wins_sc__free_cash_flow_per_share_growth  log_wins_sc___payout_ratio  \
# 0                                      0.470085                   -0.503734
# 1                                      0.034188                   -0.503734
# 2                                      0.572650                   -0.008124
# 3                                      0.076923                    0.914796
# 4                                     -2.247863                   -0.503734
#
#    log_wins_sc___dividend_payout_ratio  log_wins_sc___dividend_yield  \
# 0                            -0.503734                     -0.454883
# 1                            -0.503734                     -0.454883
# 2                            -0.008124                     -0.259375
# 3                             0.914796                      1.111632
# 4                            -0.503734                     -0.454883
#
#    ord__fiscal_year
# 0               4.0
# 1               1.0
# 2               3.0
# 3               2.0
# 4               2.0
#
# [5 rows x 51 columns]

# %%
train_prepared_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2685 entries, 0 to 2684
# Data columns (total 51 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   log_wins_sc__current_ratio                             2685 non-null   float64
#  1   log_wins_sc__quick_ratio                               2685 non-null   float64
#  2   log_wins_sc__cash_ratio                                2685 non-null   float64
#  3   log_wins_sc__days_of_sales_outstanding                 2685 non-null   float64
#  4   log_wins_sc__operating_cycle                           2685 non-null   float64
#  5   log_wins_sc__cash_conversion_cycle                     2685 non-null   float64
#  6   log_wins_sc__gross_profit_margin                       2685 non-null   float64
#  7   log_wins_sc__operating_profit_margin                   2685 non-null   float64
#  8   log_wins_sc__pretax_profit_margin                      2685 non-null   float64
#  9   log_wins_sc__net_profit_margin                         2685 non-null   float64
#  10  log_wins_sc__effective_tax_rate                        2685 non-null   float64
#  11  log_wins_sc__return_on_assets                          2685 non-null   float64
#  12  log_wins_sc__return_on_equity                          2685 non-null   float64
#  13  log_wins_sc__return_on_capital_employed                2685 non-null   float64
#  14  log_wins_sc__net_income_per_ebt                        2685 non-null   float64
#  15  log_wins_sc__ebt_per_ebit                              2685 non-null   float64
#  16  log_wins_sc__ebit_per_revenue                          2685 non-null   float64
#  17  log_wins_sc__debt_ratio                                2685 non-null   float64
#  18  log_wins_sc__debt_equity_ratio                         2685 non-null   float64
#  19  log_wins_sc__total_debt_to_capitalization              2685 non-null   float64
#  20  log_wins_sc__cash_flow_to_debt_ratio                   2685 non-null   float64
#  21  log_wins_sc__company_equity_multiplier                 2685 non-null   float64
#  22  log_wins_sc__receivables_turnover                      2685 non-null   float64
#  23  log_wins_sc__fixed_asset_turnover                      2685 non-null   float64
#  24  log_wins_sc__asset_turnover                            2685 non-null   float64
#  25  log_wins_sc__operating_cash_flow_per_share             2685 non-null   float64
#  26  log_wins_sc__free_cash_flow_per_share                  2685 non-null   float64
#  27  log_wins_sc__cash_per_share                            2685 non-null   float64
#  28  log_wins_sc__operating_cash_flow_sales_ratio           2685 non-null   float64
#  29  log_wins_sc__free_cash_flow_operating_cash_flow_ratio  2685 non-null   float64
#  30  log_wins_sc__cash_flow_coverage_ratios                 2685 non-null   float64
#  31  log_wins_sc__capital_expenditure_coverage_ratio        2685 non-null   float64
#  32  log_wins_sc__dividend_paid_and_capex_coverage_ratio    2685 non-null   float64
#  33  log_wins_sc__price_book_value_ratio                    2685 non-null   float64
#  34  log_wins_sc__price_to_book_ratio                       2685 non-null   float64
#  35  log_wins_sc__price_to_sales_ratio                      2685 non-null   float64
#  36  log_wins_sc__price_earnings_ratio                      2685 non-null   float64
#  37  log_wins_sc__price_to_free_cash_flows_ratio            2685 non-null   float64
#  38  log_wins_sc__price_to_operating_cash_flows_ratio       2685 non-null   float64
#  39  log_wins_sc__price_cash_flow_ratio                     2685 non-null   float64
#  40  log_wins_sc__price_earnings_to_growth_ratio            2685 non-null   float64
#  41  log_wins_sc__price_sales_ratio                         2685 non-null   float64
#  42  log_wins_sc__enterprise_value_multiple                 2685 non-null   float64
#  43  log_wins_sc__price_fair_value                          2685 non-null   float64
#  44  log_wins_sc__interest_coverage                         2685 non-null   float64
#  45  log_wins_sc__operating_cash_flow_per_share_growth      2685 non-null   float64
#  46  log_wins_sc__free_cash_flow_per_share_growth           2685 non-null   float64
#  47  log_wins_sc___payout_ratio                             2685 non-null   float64
#  48  log_wins_sc___dividend_payout_ratio                    2685 non-null   float64
#  49  log_wins_sc___dividend_yield                           2685 non-null   float64
#  50  ord__fiscal_year                                       2685 non-null   float64
# dtypes: float64(51)
# memory usage: 1.0 MB

# %%
train_prepared_df.describe()
# Out:
#        log_wins_sc__current_ratio  log_wins_sc__quick_ratio  \
# count                 2685.000000               2685.000000
# mean                     0.861678                  1.196685
# std                      2.488298                  3.664273
# min                     -0.670732                 -0.708920
# 25%                     -0.272358                 -0.309859
# 50%                      0.000000                  0.000000
# 75%                      0.727642                  0.690141
# max                     10.772358                 16.488263
#
#        log_wins_sc__cash_ratio  log_wins_sc__days_of_sales_outstanding  \
# count              2685.000000                             2685.000000
# mean                  0.820553                                0.288972
# std                   2.330185                                1.249468
# min                  -0.522124                               -1.082426
# 25%                  -0.309735                               -0.457797
# 50%                   0.000000                                0.000000
# 75%                   0.690265                                0.542203
# max                  10.000000                                4.497153
#
#        log_wins_sc__operating_cycle  log_wins_sc__cash_conversion_cycle  \
# count                  2.685000e+03                        2.685000e+03
# mean                  -2.376511e+08                       -3.416933e+08
# std                    1.010343e+09                        1.452875e+09
# min                   -4.539380e+09                       -6.528655e+09
# 25%                   -4.179889e-01                       -4.279795e-01
# 50%                    0.000000e+00                        0.000000e+00
# 75%                    5.820111e-01                        5.720205e-01
# max                    3.604612e+00                        3.015211e+00
#
#        log_wins_sc__gross_profit_margin  log_wins_sc__operating_profit_margin  \
# count                       2685.000000                           2685.000000
# mean                           0.100029                              0.091688
# std                            0.646646                              0.923969
# min                           -0.915493                             -1.939394
# 25%                           -0.408451                             -0.454545
# 50%                            0.000000                              0.000000
# 75%                            0.591549                              0.545455
# max                            1.225352                              2.272727
#
#        log_wins_sc__pretax_profit_margin  log_wins_sc__net_profit_margin  ...  \
# count                        2685.000000                     2685.000000  ...
# mean                            0.046699                        0.042682  ...
# std                             0.894099                        0.959416  ...
# min                            -2.096774                       -2.320000  ...
# 25%                            -0.419355                       -0.440000  ...
# 50%                             0.000000                        0.000000  ...
# 75%                             0.580645                        0.560000  ...
# max                             1.935484                        2.160000  ...
#
#        log_wins_sc__price_sales_ratio  log_wins_sc__enterprise_value_multiple  \
# count                     2685.000000                             2685.000000
# mean                         0.366802                                0.122452
# std                          1.006479                                1.513901
# min                         -0.596343                               -3.869806
# 25%                         -0.329114                               -0.449215
# 50%                          0.000000                                0.000000
# 75%                          0.670886                                0.550785
# max                          3.334740                                4.407202
#
#        log_wins_sc__price_fair_value  log_wins_sc__interest_coverage  \
# count                    2685.000000                     2685.000000
# mean                        0.486434                        0.799867
# std                         1.381516                        2.431481
# min                        -1.259300                       -1.400404
# 25%                        -0.289934                       -0.318788
# 50%                         0.000000                        0.000000
# 75%                         0.710066                        0.681212
# max                         5.242888                       10.165657
#
#        log_wins_sc__operating_cash_flow_per_share_growth  \
# count                                        2685.000000
# mean                                            0.021346
# std                                             1.741979
# min                                            -4.835616
# 25%                                            -0.465753
# 50%                                             0.000000
# 75%                                             0.534247
# max                                             4.657534
#
#        log_wins_sc__free_cash_flow_per_share_growth  \
# count                                   2685.000000
# mean                                      -0.022435
# std                                        1.707122
# min                                       -4.470085
# 25%                                       -0.521368
# 50%                                        0.000000
# 75%                                        0.478632
# max                                        4.555556
#
#        log_wins_sc___payout_ratio  log_wins_sc___dividend_payout_ratio  \
# count                 2685.000000                          2685.000000
# mean                     0.175602                             0.175602
# std                      0.752791                             0.752791
# min                     -0.503734                            -0.503734
# 25%                     -0.503734                            -0.503734
# 50%                      0.000000                             0.000000
# 75%                      0.496266                             0.496266
# max                      2.401867                             2.401867
#
#        log_wins_sc___dividend_yield  ord__fiscal_year
# count                   2685.000000       2685.000000
# mean                       0.187332          2.373929
# std                        0.673157          1.175472
# min                       -0.454883          0.000000
# 25%                       -0.454883          1.000000
# 50%                        0.000000          2.000000
# 75%                        0.545117          3.000000
# max                        2.005645          5.000000
#
# [8 rows x 51 columns]

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train_prepared_df['log_wins_sc__return_on_capital_employed'], bins=50, kde=True)
plt.title(f"Distribution {'return_on_capital_employed'}")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(train_prepared_df['log_wins_sc__net_profit_margin'], bins=50, kde=True)
plt.title(f"Distribution {'net_profit_margin'}")
plt.show()

# %% [markdown]
# # Regression Models

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lin_reg = make_pipeline(preprocessing, LinearRegression())

# %%
from sklearn.model_selection import cross_val_score

lin_rmses = -cross_val_score(lin_reg, train, train_label,
                              scoring="neg_root_mean_squared_error", cv=10)

pd.Series(lin_rmses).describe()
# Out:
# count    1.000000e+01
# mean     2.711402e+11
# std      2.541983e+11
# min      2.397109e+10
# 25%      8.179495e+10
# 50%      1.519598e+11
# 75%      4.755633e+11
# max      7.507405e+11
# dtype: float64

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.linear_model import Ridge

ridge_reg = make_pipeline(preprocessing, Ridge(alpha=100, solver="cholesky"))

# %%
ridge_rmses = -cross_val_score(ridge_reg, train, train_label,
                              scoring="neg_root_mean_squared_error", cv=10)

pd.Series(ridge_rmses).describe()
# Out:
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=7.65089e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.16497e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.12798e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.64609e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.07027e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.05852e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.12146e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=3.66006e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.12528e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/gonzalocaro/Desktop/Empresas - Trabajos/IUMA/Python/Practicas-ML-NN/PracticasIUMA/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.0878e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# count    1.000000e+01
# mean     3.925149e+11
# std      2.304470e+11
# min      1.116684e+11
# 25%      2.251148e+11
# 50%      3.495089e+11
# 75%      5.815569e+11
# max      7.714669e+11
# dtype: float64

# %% [markdown]
# ##  RANSACRegressor

# %%
from sklearn.linear_model import RANSACRegressor

ransac_reg = make_pipeline(preprocessing, RANSACRegressor())

# %%
ransac_rmses = -cross_val_score(ransac_reg, train, train_label,
                              scoring="neg_root_mean_squared_error", cv=10)

pd.Series(ransac_rmses).describe()
# Out:
# count    1.000000e+01
# mean     2.175124e+12
# std      1.804667e+12
# min      4.334262e+09
# 25%      9.816575e+11
# 50%      1.580937e+12
# 75%      3.117384e+12
# max      5.724080e+12
# dtype: float64

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

rdf_reg = make_pipeline(preprocessing, RandomForestRegressor(min_samples_leaf=10, min_samples_split=15, max_depth=5, random_state=42))

# %%
rdf_rmses = -cross_val_score(rdf_reg, train, train_label,
                              scoring="neg_root_mean_squared_error", cv=10)

pd.Series(rdf_rmses).describe()
# Out:
# count    10.000000
# mean      0.610116
# std       0.080246
# min       0.498142
# 25%       0.547578
# 50%       0.599578
# 75%       0.660071
# max       0.750280
# dtype: float64

# %%
relative_rmse_rdf_reg = rdf_rmses.mean() / train_label.mean()
relative_rmse_rdf_reg.round(2)
# Out:
# 5.77

# %%
rdf_reg.fit(train, train_label)

rdf_model = rdf_reg.named_steps['randomforestregressor']
importances = rdf_model.feature_importances_

feature_names_out = preprocessing.get_feature_names_out()

# %%
feature_importance = pd.DataFrame({
    'Feature': feature_names_out,
    'Importance': importances
})

feature_importance = feature_importance.sort_values(by='Importance', ascending=False).reset_index(drop=True)

feature_importance
# Out:
#                                               Feature  Importance
# 0                                    ord__fiscal_year    0.241590
# 1                      log_wins_sc__net_profit_margin    0.072427
# 2                   log_wins_sc__price_earnings_ratio    0.070357
# 3                        log_wins_sc___dividend_yield    0.061459
# 4                   log_wins_sc__price_to_sales_ratio    0.048338
# 5                      log_wins_sc__price_sales_ratio    0.046453
# 6                       log_wins_sc__return_on_assets    0.044002
# 7   log_wins_sc__operating_cash_flow_per_share_growth    0.041662
# 8                      log_wins_sc__interest_coverage    0.026318
# 9                 log_wins_sc__price_book_value_ratio    0.020649
# 10                      log_wins_sc__return_on_equity    0.019313
# 11        log_wins_sc__price_earnings_to_growth_ratio    0.016328
# 12       log_wins_sc__free_cash_flow_per_share_growth    0.016320
# 13                      log_wins_sc__price_fair_value    0.015881
# 14             log_wins_sc__company_equity_multiplier    0.014623
# 15                  log_wins_sc__pretax_profit_margin    0.014190
# 16             log_wins_sc__days_of_sales_outstanding    0.013368
# 17                   log_wins_sc__price_to_book_ratio    0.012348
# 18  log_wins_sc__dividend_paid_and_capex_coverage_...    0.012158
# 19                   log_wins_sc__gross_profit_margin    0.011664
# 20                         log_wins_sc__current_ratio    0.011304
# 21                        log_wins_sc__cash_per_share    0.010444
# 22                        log_wins_sc__asset_turnover    0.009880
# 23                           log_wins_sc__quick_ratio    0.008966
# 24            log_wins_sc__return_on_capital_employed    0.008892
# 25                  log_wins_sc__fixed_asset_turnover    0.008545
# 26             log_wins_sc__enterprise_value_multiple    0.008142
# 27   log_wins_sc__price_to_operating_cash_flows_ratio    0.007458
# 28                    log_wins_sc__net_income_per_ebt    0.007111
# 29                    log_wins_sc__effective_tax_rate    0.006891
# 30                            log_wins_sc__debt_ratio    0.006705
# 31                 log_wins_sc__price_cash_flow_ratio    0.006670
# 32                  log_wins_sc__receivables_turnover    0.006611
# 33    log_wins_sc__capital_expenditure_coverage_ratio    0.006475
# 34                          log_wins_sc__ebt_per_ebit    0.005969
# 35        log_wins_sc__price_to_free_cash_flows_ratio    0.005836
# 36                 log_wins_sc__cash_conversion_cycle    0.005582
# 37         log_wins_sc__operating_cash_flow_per_share    0.005376
# 38                            log_wins_sc__cash_ratio    0.004967
# 39              log_wins_sc__free_cash_flow_per_share    0.004743
# 40                     log_wins_sc__debt_equity_ratio    0.004516
# 41                       log_wins_sc__operating_cycle    0.004420
# 42       log_wins_sc__operating_cash_flow_sales_ratio    0.004296
# 43                         log_wins_sc___payout_ratio    0.004130
# 44  log_wins_sc__free_cash_flow_operating_cash_flo...    0.003828
# 45                      log_wins_sc__ebit_per_revenue    0.002964
# 46          log_wins_sc__total_debt_to_capitalization    0.002932
# 47                log_wins_sc___dividend_payout_ratio    0.002795
# 48             log_wins_sc__cash_flow_coverage_ratios    0.001890
# 49               log_wins_sc__cash_flow_to_debt_ratio    0.001522
# 50               log_wins_sc__operating_profit_margin    0.000692

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBRegressor

xgb_reg = make_pipeline(preprocessing, XGBRegressor(random_state=42))

# %%
xgb_rmses = -cross_val_score(xgb_reg, train, train_label,
                              scoring="neg_root_mean_squared_error", cv=10)

pd.Series(xgb_rmses).describe()
# Out:
# count    10.000000
# mean      0.894533
# std       0.195571
# min       0.698479
# 25%       0.803778
# 50%       0.840532
# 75%       0.897105
# max       1.410779
# dtype: float64

# %%
xgb_reg.fit(train, train_label)

xgb_model = xgb_reg.named_steps['xgbregressor']
importances = xgb_model.feature_importances_

feature_names_out = preprocessing.get_feature_names_out()

# %%
feature_importance = pd.DataFrame({
    'Feature': feature_names_out,
    'Importance': importances
})

feature_importance = feature_importance.sort_values(by='Importance', ascending=False).reset_index(drop=True)

feature_importance
# Out:
#                                               Feature  Importance
# 0                                    ord__fiscal_year    0.169192
# 1                      log_wins_sc__net_profit_margin    0.056686
# 2                        log_wins_sc___dividend_yield    0.053354
# 3                   log_wins_sc__price_to_sales_ratio    0.039063
# 4                   log_wins_sc__price_earnings_ratio    0.038405
# 5                         log_wins_sc__asset_turnover    0.035145
# 6   log_wins_sc__operating_cash_flow_per_share_growth    0.031878
# 7                      log_wins_sc__interest_coverage    0.031326
# 8                 log_wins_sc__price_book_value_ratio    0.028286
# 9                       log_wins_sc__return_on_equity    0.025221
# 10                     log_wins_sc__debt_equity_ratio    0.022008
# 11       log_wins_sc__free_cash_flow_per_share_growth    0.020673
# 12        log_wins_sc__price_earnings_to_growth_ratio    0.020161
# 13    log_wins_sc__capital_expenditure_coverage_ratio    0.019737
# 14                        log_wins_sc__cash_per_share    0.019176
# 15        log_wins_sc__price_to_free_cash_flows_ratio    0.018386
# 16          log_wins_sc__total_debt_to_capitalization    0.017096
# 17              log_wins_sc__free_cash_flow_per_share    0.017081
# 18                   log_wins_sc__gross_profit_margin    0.016876
# 19            log_wins_sc__return_on_capital_employed    0.016513
# 20  log_wins_sc__dividend_paid_and_capex_coverage_...    0.016030
# 21       log_wins_sc__operating_cash_flow_sales_ratio    0.015880
# 22         log_wins_sc__operating_cash_flow_per_share    0.015455
# 23   log_wins_sc__price_to_operating_cash_flows_ratio    0.015349
# 24                    log_wins_sc__net_income_per_ebt    0.015240
# 25             log_wins_sc__enterprise_value_multiple    0.015073
# 26                    log_wins_sc__effective_tax_rate    0.014844
# 27               log_wins_sc__cash_flow_to_debt_ratio    0.014740
# 28             log_wins_sc__company_equity_multiplier    0.014357
# 29                  log_wins_sc__fixed_asset_turnover    0.013927
# 30                          log_wins_sc__ebt_per_ebit    0.013724
# 31                      log_wins_sc__return_on_assets    0.013658
# 32             log_wins_sc__days_of_sales_outstanding    0.013276
# 33  log_wins_sc__free_cash_flow_operating_cash_flo...    0.012876
# 34               log_wins_sc__operating_profit_margin    0.012506
# 35                         log_wins_sc___payout_ratio    0.011368
# 36                            log_wins_sc__debt_ratio    0.011275
# 37                           log_wins_sc__quick_ratio    0.010972
# 38                            log_wins_sc__cash_ratio    0.010209
# 39                 log_wins_sc__cash_conversion_cycle    0.009783
# 40                         log_wins_sc__current_ratio    0.009512
# 41                       log_wins_sc__operating_cycle    0.008805
# 42                  log_wins_sc__receivables_turnover    0.008005
# 43                  log_wins_sc__pretax_profit_margin    0.006869
# 44                     log_wins_sc__price_sales_ratio    0.000000
# 45                 log_wins_sc__price_cash_flow_ratio    0.000000
# 46                      log_wins_sc__price_fair_value    0.000000
# 47                   log_wins_sc__price_to_book_ratio    0.000000
# 48                      log_wins_sc__ebit_per_revenue    0.000000
# 49                log_wins_sc___dividend_payout_ratio    0.000000
# 50             log_wins_sc__cash_flow_coverage_ratios    0.000000

# %% [markdown]
# # Simplifiyng the Data Set

# %%
ratios = [
    "net_profit_margin", "return_on_equity", "return_on_capital_employed",  # Profitability
    "asset_turnover",  # Eficciency
    "current_ratio", "debt_equity_ratio", "interest_coverage",  # Liquidity and Solvency
    "price_to_free_cash_flows_ratio", "price_earnings_ratio", "price_book_value_ratio",  # Valuation
    'operating_cash_flow_per_share_growth', 'free_cash_flow_per_share_growth','price_earnings_to_growth_ratio'  # Growth
] 

dividend_ratios = ['dividend_yield']

new_columns = ratios + dividend_ratios + ['fiscal_year']

# %%
train = train_set[new_columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import RobustScaler
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import FunctionTransformer


def preprocess_column(X):
    X_log = np.log1p(X - X.min() + 1)  
    X_wins = winsorize(X_log, limits=(0.04, 0.04), axis=0)  
    return np.array(X_wins)

ratio_pipeline = make_pipeline(KNNImputer(n_neighbors=5) ,FunctionTransformer(preprocess_column, feature_names_out="one-to-one"), 
                               RobustScaler())

dividend_pipeline = make_pipeline(SimpleImputer(strategy='constant', fill_value=0) ,FunctionTransformer(preprocess_column, feature_names_out="one-to-one"), 
                               RobustScaler())

ord_pipeline = make_pipeline(ordinal_encoder) 

preprocessing = ColumnTransformer([
        ("log_wins_sc", ratio_pipeline, ratios),
        ("log_wins_sc_", dividend_pipeline, dividend_ratios),
        ("ord", ord_pipeline, ['fiscal_year']),
    ],
    remainder='passthrough')

# %%
train_prepared = preprocessing.fit_transform(train)
train_prepared.shape
# Out:
# (2685, 15)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lin_reg = make_pipeline(preprocessing, LinearRegression())

# %%
from sklearn.model_selection import cross_val_score

lin_rmses = -cross_val_score(lin_reg, train, train_label,
                              scoring="neg_root_mean_squared_error", cv=10)

pd.Series(lin_rmses).describe()
# Out:
# count        10.000000
# mean     205895.187855
# std      132751.860033
# min       27726.094491
# 25%      133069.992393
# 50%      172283.363982
# 75%      302585.895441
# max      435301.270589
# dtype: float64

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

rdf_reg = make_pipeline(preprocessing, RandomForestRegressor(min_samples_leaf=10, min_samples_split=15, max_depth=5, random_state=42))

# %%
rdf_rmses = -cross_val_score(rdf_reg, train, train_label,
                              scoring="neg_root_mean_squared_error", cv=10)

pd.Series(rdf_rmses).describe()
# Out:
# count    10.000000
# mean      0.439175
# std       0.063421
# min       0.328083
# 25%       0.399241
# 50%       0.442882
# 75%       0.467433
# max       0.560768
# dtype: float64

# %%
rdf_reg.fit(train, train_label)
y_pred_rdf = rdf_reg.predict(train)

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=train_label, y=y_pred_rdf, color='#A3D9A5', alpha=0.9)
sns.lineplot(x=[min(train_label), max(train_label)], 
             y=[min(train_label), max(train_label)], 
             color='#2E2E2E', linestyle='--')
plt.xlabel('Real Returns')
plt.ylabel('Predicted Returns')
plt.title('Real vs Predicted Returns')
plt.show()
